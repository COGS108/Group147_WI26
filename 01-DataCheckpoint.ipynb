# %% [markdown]
# ## Rubric
#
#
#
# Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
# |                  | Unsatisfactory                                                                                                                                                                                                    | Developing                                                                                                                                                                                              | Proficient                                     | Excellent                                                                                                                              |
# |------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------|
# | Data relevance   | Did not have data relevant to their question. Or the datasets don't work together because there is no way to line them up against each other. If there are multiple datasets, most of them have this trouble | Data was only tangentially relevant to the question or a bad proxy for the question. If there are multiple datasets, some of them may be irrelevant or can't be easily combined.                       | All data sources are relevant to the question. | Multiple data sources for each aspect of the project. It's clear how the data supports the needs of the project.                         |
# | Data description | Dataset or its cleaning procedures are not described. If there are multiple datasets, most have this trouble                                                                                              | Data was not fully described. If there are multiple datasets, some of them are not fully described                                                                                                      | Data was fully described                       | The details of the data descriptions and perhaps some very basic EDA also make it clear how the data supports the needs of the project. |
# | Data wrangling   | Did not obtain data. They did not clean/tidy the data they obtained.  If there are multiple datasets, most have this trouble                                                                                 | Data was partially cleaned or tidied. Perhaps you struggled to verify that the data was clean because they did not present it well. If there are multiple datasets, some have this trouble | The data is cleaned and tidied.                | The data is spotless and they used tools to visualize the data cleanliness and you were convinced at first glance                      |

# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
# - Athena Vimal: Background research, conceptualization, Writing – original draft, Writing – review & editing
# - Lucy Pan: Conceptualization, Data curation, Writing – original draft, Writing – review & editing, Project administration
# - Kimberly Haro: Background research, data curation, writing– original draft, and writing– review & editing
# - Ruth Mazariego: Conceptualization, Hypothesis, Data curation, writing– original draft, and writing– review & editing
# - Duglas Zacarias: Data curation, Background research, Writing – original draft, Writing – review & editing

# %% [markdown]
# ## Research Question

# %% [markdown]
# How do U.S. counties hosting large-scale data centers differ from comparable non-host counties in terms of economic outcomes (employment growth, municipal tax revenue) and environmental impacts (CO₂ emissions, and electricity use)?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Technology has been invented in order to make human lives easier, but as this technology keeps evolving, the world starts changing too. With the invention of artificial intelligence (AI), many controversies have come up when it comes to the benefits and disadvantages that it brings to the environment, the economy, education, and our everyday life. Some studies suggest that AI can support environmental sustainability by improving efficiency, energy systems and allow better monitoring of environmental conditions[1](#cite_ref-1) [2](##cite_ref-2). At the same time, the fast expansion of AI has created new forms of resource demand that raise sustainability concerns. As AI data centers increase across economic sections, understanding both its potential benefits and environmental consequences has become very important.
#
# AI systems rely on very large computer infrastructure that is mainly located in data centers in order to support tasks such as cloud computing, machine learning training, and large data processing. Reviews of data center operations indicate that energy intensive servers and cooling systems make these facilities among the fastest growing sources of industrial electricity consumption worldwide. [3](#cite_ref-3) In the United States, the growth of AI has contributed to a fast expansion of data centers infrastructure, increasing overall demand for electricity and placing tension on power systems.[4](#cite_ref-4) As AI continues to grow, the physical infrastructure needed to support these technologies has become a main factor in looking at sustainability.
#
# Studies demonstrate that data centers contribute to a significant and growing environmental burden in the AI era. Guidi et al, find that U.S. data centers consume a major portion of national electricity and that AI data centers are only increasing this. Large chunks of data centers can put tension on regional power grids, increase peak demand, and sometimes prolong dependency on carbon intensive energy sources.[5](#cite_ref-5) In addition to energy consumption, water usage for cooling is a major concern, especially in dry regions. Although solutions like advanced cooling systems, waste heat reuse, and water positive designs have been proposed, their adoption remains inconsistent across facilities.[6](#cite_ref-6) Together, these studies show that AI data centers generate major environmental impacts related to electricity demand, greenhouse emissions, and water consumption.
#
# In addition to environmental concerns, data centers are often promoted as an economic growth impact in host communities. Research indicates that regulatory environments can increase data center valuation, and attract private investment, encouraging companies to locate large facilities in certain regions.[7](#cite_ref-7) Data centers may also contribute to local tax revenue infrastructure development and employment opportunities, particularly in technology and engineering sections.[8](#cite_ref-8) However, community research suggests that these economic benefits are often going along with local costs, including increased demand for electricity and water, land use pressure, and environmental stress.[9](#cite_ref-9) While prior work studies have examined economic outcomes or environmental impacts separately, only a few directly compare these topics at the county level across the United States. The lack of research motivates a modified evaluation of how U.S. counties hosting large-scale data centers differ from comparable non-hosting counties in terms of environmental impacts (CO2 emissions, electricity use, and water consumption) and economic outcomes (employment growth and municipal tax revenue).
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Oluwaseun, A. Analyzing How AI Impacts Environmental Sustainability: A Case Study for the USA.
# https://doi.org/10.21203/rs.3.rs-5953542/v1
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Kirikkaleli, D., et al. Environmental Sustainability in the USA: Role of Artificial Intelligence. Sustainable Futures.
# https://doi.org/10.1016/j.sftr.2025.100823
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3)Raphael, D., et al. Impact of Data Centers on Climate Change: A Review of Energy Efficient Strategies.
# https://www.researchgate.net/profile/Ochuko-Orikpete/publication/373295068_Impact_of_Data_Centers_on_Climate_Change_A_Review_of_Energy_Efficient_Strategies/links/64e505820453074fbda78c3f/Impact-of-Data-Centers-on-Climate-Change-A-Review-of-Energy-Efficient-Strategies.pdf
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4)Guidi, G., et al. Environmental Burden of United States Data Centers in the Artificial Intelligence Era.
# https://arxiv.org/pdf/2411.09786
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5)Chen, X., et al. Electricity Demand and Grid Impacts of AI Data Centers: Challenges and Prospects.
# https://arxiv.org/pdf/2509.07218
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6)Díaz-Marín, C. D., & Berquist, Z. J. Flipping the Switch: Carbon-Negative and Water-Positive Data Centers Through Waste Heat Utilization.
# https://pubs.rsc.org/en/content/articlelanding/2025/ee/d5ee02676h
# 7. <a name="cite_note-7"></a> [^](#cite_ref-7)Lee, D. Impact of Environmental Regulation on Data Center Valuation. MIT Master’s Thesis.
# https://dspace.mit.edu/bitstream/handle/1721.1/158830/Lee-dhlee23-msred-cre-2025-Thesis.pdf?sequence=1&isAllowed=y
# 8. <a name="cite_note-8"></a> [^](#cite_ref-8)Berger, A. Artificial Intelligence Data Centers and United States-Based Hyperscalers: Impacts and Solutions.
# https://jscholarship.library.jhu.edu/items/8792d5a5-91a3-4179-bc73-61fcc2ae187
# 9. <a name="cite_note-9"></a> [^](#cite_ref-9)Ngata, W., et al. The Cloud Next Door: Investigating the Environmental and Socioeconomic Strain of Datacenters on Local Communities.
# https://dl.acm.org/doi/10.1145/3715335.3736324

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that counties hosting large-scale data centers will experience higher CO₂ emissions and electricity usage, but also higher employment growth and GDP, compared to comparable counties without data centers.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: Data Centers in the US
#   - Link to the dataset: https://data.msdlive.org/records/65g71-a4731
#   - Number of observations: 1479
#   - Number of variables: 13
#   - Description of the variables most relevant to this project:
# <br> state: The state where the data center is
# <br> county: The county where the data center is
# <br> sqft: The area in square feet of the data center
#   - Descriptions of any shortcomings this dataset has with respect to the project
# <br> Doesn't contain the date in which the data center was opened.
#
# - Dataset #2
#   - Dataset Name: County GDP summary- percent change from preceding period
#   - Link to the dataset: https://apps.bea.gov/itable/?ReqID=70&step=1&_gl=1*1fpvxvi*_ga*MTgyMzE3ODI5My4xNzcxNDYxNzcw*_ga_J4698JNNFT*czE3NzE0NjE3NjkkbzEkZzEkdDE3NzE0NjM2NDQkajM5JGwwJGgw#
#   - Number of observations: 3138
#   - Number of variables: 5
#   - Description of the variables most relevant to this project
# <br> GeoName: The county name with the related state abbreviation
# <br> 2022: The percent change in county GDP from 2021
# <br> 2023: The percent change in county GDP from 2022
# <br> 2024: The percent change in county GDP from 2024
#   - Descriptions of any shortcomings this dataset has with respect to the project
# <br>
# High level of aggregation thus missing out on variability.
# - Dataset #3
#   - Dataset Name: CO2 emission (in U.S)
#   - Link to the dataset: https://www.kaggle.com/datasets/alistairking/u-s-co2-emissions
#   - Number of observations: 59901
#   - Number of variables: 5
#   - Description of the variables most relevant to this project
#         Sector name: This could allow us to use certain sectors where AI datacenters are located.
#         Value: Amount of emissions in million metric tons of CO2.
#         Year: It would help us compare how the increased use of AI influenced the amount of CO2 emissions created.
#   - Descriptions of any shortcomings this dataset has with repsect to the project:
#       - The dataset contains a lot information about the many sectors that create carbon dioxide emissions, but I believe that we should be able to filter the data to only focus on the “Industrial carbon dioxide emission” or A.I. datacenter related sectors in the US.
#       - Not sure if the measurement used for CO2 emission would be a problem in the future.
#       - The last data year entry was in 2021 which may or many not be considered recent.
#   - Ideas: This dataset could be used to calculate environmental costs since is one of the environmental damages that datacenters do. And it would also help to calculate in total how much CO2 do counties in a state produce or to compare between states hosting and not hosting A.I. datacenters.
#
# - Dataset #4:
#   - Dataset Name: USGS Estimated Use of Water in the United States — County-Level Data (2015)
#   - Source: https://water.usgs.gov/watuse/data/
#   - Geographic Level: County
#   - Time Period: 2015
#   - Number of Observations: ~3,000 counties
#   - Key Variables: Total water withdrawals (Mgal/day), Public supply, Industrial, Thermoelectric power
#   - Limitations: Reported every 5 years rather than annually.
#
#
# - Dataset #5
#     - Dataset Name: Average Retail Price of Electricity (state level)
#     - Link to dataset: https://www.eia.gov/electricity/data/browser/#/topic/7?agg=1,0&geo=vvvvvvvvvvvvo&endsec=4&freq=M&start=200101&end=202511&ctype=linechart&ltype=pin&rtype=s&pin=&rse=0&maptype=0
#     - Source: U.S. Energy Information Administration (EIA)
#     - Geographic level: State
#     - Time period January 2001-November 2025 (monthly data)
#     - Number of observations: 65 rows (states, regions, and national aggregates)
#     - Number of variables: ~302 variables (description, units, source key, monthly price columns)
#     - Key variables: decription (identifies the geographic area and sector), units (electricity price measured in cents per kilowatt-hour), source key (EIA series identifier), and monthly price columns (Jan 2001-Nov 2025, average reatail electricity prices per each month).
#     - Description of variables most relevant: This dataset provides average residential electricity prices by U.S. state over time, measured in cents per kilowatt-hour. The data captures monthly price variation across states, allowing comparisons of electricity cost trends over time and across regions.
#     - Limitations: A key limitation of this dataset is that electricity prices are reported at the state level rather than the ciunty level. The data can't caoture within state variation in electricity prices, which limits its ability to specifically align with county level data on data center locations. Also, state level averages may cover local price differences that could be relevant when analyzing the impacts of invidual data centers. Despite this limitation, state level electricity prices still provide useful information when comparing broarder cost patterns that are associated with data center activity.
#
#
# Each dataset deserves either a set of bullet points as above or a few sentences if you prefer that method.
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.
#
# Each dataset deserves either a set of bullet points as above or a few sentences if you prefer that method.
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=1QIQEXyJFnfvVRdXEb4X4XXXIPql21dlD', 'filename':'datacenters.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1rJnAzG1hrLeIhdGgAQmpKnX_Jsw6qCxv', 'filename':'countygdp.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1HF88A6hK9vrwKZgEgr6i7Ex7zv-92Rmx', 'filename': 'electricity_price_state.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1rCMbPBhKfvNKQsNW-1qHwbHqK-s7vLx8', 'filename': 'emissions.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1zOvBrMLBwcu-DN2BCY-ik-3T04q5MtVC', 'filename': 'usgs_water_use_county_2015.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress:  20%|██        | 1/5 [00:01<00:05,  1.28s/it][A
# Successfully downloaded: datacenters.csv
# ...
# Overall Download Progress:  40%|████      | 2/5 [00:02<00:04,  1.36s/it]
# Successfully downloaded: countygdp.csv
# ...
# Overall Download Progress:  60%|██████    | 3/5 [00:04<00:02,  1.34s/it]
# Successfully downloaded: electricity_price_state.csv
# ...
# Overall Download Progress:  80%|████████  | 4/5 [00:06<00:01,  1.66s/it]
# Successfully downloaded: emissions.csv
# ...
# Overall Download Progress: 100%|██████████| 5/5 [00:08<00:00,  1.62s/it]
# Successfully downloaded: usgs_water_use_county_2015.csv

# %% [markdown]
# ### Dataset #1- Data Center facilities in the US
#
# This dataset is located at https://data.msdlive.org/records/65g71-a4731 and contains the location of data centers in the US as of February 2026. The data was acquired from OpenStreetMap, a crowd sourced database.
#
# The important variables in this data set are state, county, sqft and potentially operator. This dataset is a valuable source for finding the updated geographic locations of data centers in the US (state, county). Sqft variable will be helpful in calculating our electricity use metric which involves kwh per sqft of the data center.
#
# The concern with this dataset is that it does not contain the dates that the data center opened. That particular data seems to be on this website: https://www.datacentermap.com/research/, but needs to be requested. It is important to have the dates in order to conduct analysis with changes in time.
#
# The source is largely credible as it was done by an agency sponsored by the US Department of Energy.

# %%
import pandas as pd

# %%
## A. this is a preview of the dataset
df_datacenters = pd.read_csv('data/00-raw/datacenters.csv')
df_datacenters.head()
# Out:
#          id           state state_abb  state_id             county  county_id  \
# 0   2744301      New Jersey        NJ        34   Middlesex County         23
# 1   9474864  North Carolina        NC        37    Caldwell County         27
# 2  13924557            Iowa        IA        19        Polk County        153
# 3  14593270  North Carolina        NC        37     Catawba County         35
# 4  14930068      New Mexico        NM        35  Bernalillo County          1
#
#                        operator  ref                        name        sqft  \
# 0                           NaN  NaN                     Verizon    105786.0
# 1                        Google  NaN          Google Data Center   3407194.0
# 2                     Microsoft  NaN            Project Alluvion  11169421.0
# 3                           NaN  NaN  Apple - Maiden Data Center   5431080.0
# 4  Sandia National Laboratories  880                         HPC    158463.0
#
# ...

# %% [markdown]
# #### Dataset #1- B. tidy dataset
# This dataset is already tidy as each column refers to a variable, each row is an observation and the data is in a consistent format. However, there are some null values, primarily in the operator, and ref columns. However, these variables are less relevant to our research question. I will address these missing values more in F.

# %%
## C. this is the size of the dataset
df_datacenters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1479 entries, 0 to 1478
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         1479 non-null   int64
#  1   state      1479 non-null   object
#  2   state_abb  1479 non-null   object
#  3   state_id   1479 non-null   int64
#  4   county     1479 non-null   object
#  5   county_id  1479 non-null   int64
#  6   operator   960 non-null    object
#  7   ref        374 non-null    object
#  8   name       1204 non-null   object
#  9   sqft       1374 non-null   float64
#  10  lon        1479 non-null   float64
#  11  lat        1479 non-null   float64
#  12  type       1479 non-null   object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 150.3+ KB

# %% [markdown]
# #### Dataset #1 D. missing data
# As we can see above, the columns that contain missing data are operate, ref, name and sqft. It appears that the missing data is quite random.

# %%
missing_operator = df_datacenters[df_datacenters['operator'].isna()]
missing_ref = df_datacenters[df_datacenters['ref'].isna()]
missing_name = df_datacenters[df_datacenters['name'].isna()]
missing_sqft = df_datacenters[df_datacenters['sqft'].isna()]
print("Values missing in column 'operator':", missing_operator.shape[0])
print("Values missing in column 'ref':", missing_ref.shape[0])
print("Values missing in column 'name':", missing_name.shape[0])
print("Values missing in column 'sqft':", missing_sqft.shape[0])
# Out:
# Values missing in column 'operator': 519
# Values missing in column 'ref': 1105
# Values missing in column 'name': 275
# Values missing in column 'sqft': 105

# %% [markdown]
# #### Dataset #1 E. outliers
# This dataset is unlikely to contain many outliers as most variables are categorical. I also will check for duplicates.

# %%
import matplotlib.pyplot as plt

plt.scatter(df_datacenters['lon'], df_datacenters['lat'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Datacenter Locations')
plt.show()

# %%
# the outlier shown above- in Puerto Rico. not very crazy or relevant..
df_datacenters[(df_datacenters['lat'] < 20) & (df_datacenters['lon'] > -70)]
# Out:
#                id        state state_abb  state_id              county  \
# 299     365941471  Puerto Rico        PR        72  San Juan Municipio
# 1421  10014176940  Puerto Rico        PR        72  Guaynabo Municipio
#
#       county_id   operator  ref       name     sqft        lon        lat  \
# 299         127      Claro  NaN        NaN  23137.0 -66.051687  18.446827
# 1421         61  Microsoft  NaN  Microsoft      NaN -66.108990  18.417436
#
#           type
# 299   building
# 1421     point

# %%
#no duplicates
df_datacenters.duplicated().any()
# Out:
# False

# %% [markdown]
# #### Dataset #1 F. clean data
# To clean the data, I will drop irrelevant columns, and show the datatypes are correct for the desired calculations. I will also remove the word County from the entries in county.

# %%
## Dataset #1 F.clean data
df_datacenters = df_datacenters.drop(columns=['state_abb',
                                              'state_id',
                                              'county_id',
                                              'ref',
                                              'lon',
                                              'lat',
                                              'type',
                                              'operator',
                                              'name'])

# %%
## Dataset #1 F.clean data- renaming entries in county
df_datacenters['county'] = df_datacenters['county'].str.replace('County', '', regex=False)
df_datacenters
# Out:
#                id           state       county        sqft
# 0         2744301      New Jersey   Middlesex     105786.0
# 1         9474864  North Carolina    Caldwell    3407194.0
# 2        13924557            Iowa        Polk   11169421.0
# 3        14593270  North Carolina     Catawba    5431080.0
# 4        14930068      New Mexico  Bernalillo     158463.0
# ...           ...             ...          ...         ...
# 1474  13226718075       Wisconsin        Dane          NaN
# 1475  13311012216          Nevada       Clark          NaN
# 1476  13409186015    Pennsylvania  Montgomery          NaN
# 1477  13465438761           Texas      Dallas          NaN
# 1478  13527396782      Washington   Snohomish          NaN
#
# [1479 rows x 4 columns]

# %%
# getting rid of excess space after county names
df_datacenters['county'] = df_datacenters['county'].str.strip()
df_datacenters['county'].unique()
# Out:
# array(['Middlesex', 'Caldwell', 'Polk', 'Catawba', 'Bernalillo',
#        'Henrico', 'Union', 'Anne Arundel', 'Madison', 'Cass',
#        'Prince William', 'Crook', 'Tarrant', 'Dallas', 'Los Angeles',
#        'Warren', 'San Diego', 'Sacramento', 'Fulton', 'Santa Clara',
#        'Hamilton', 'St. Louis city', 'Hennepin', 'Loudoun', 'Washington',
#        'Carver', 'Denver', 'Albany', 'Wayne', 'Strafford', 'Fairfax',
#        'Rockingham', 'Montgomery', 'Hudson', 'Bexar',
#        'Greater Bridgeport Planning Region', 'DuPage', 'Cook', 'Ramsey',
#        'Maricopa', 'Champaign', 'Clark', 'Douglas', 'Allegheny',
#        'Frederick', 'Pottawattamie', 'San Francisco', 'Platte', 'Tulsa',
#        'Arapahoe', 'Monroe', 'King', 'Essex', 'Mecklenburg', 'Fauquier',
#        'Laramie', 'Wasco', 'Wake', 'Minnehaha', 'Salt Lake', 'Richmond',
#        'New York', 'Collin', 'Grant', 'Cobb', 'Lehigh', 'Lake',
#        'Santa Fe', 'Jefferson', 'Philadelphia', 'Spokane',
# ...

# %% [markdown]
# #### Dataset #1 summary statistics

# %%
## which counties have the most data centers?
df_datacenters.groupby('county').size().sort_values(ascending=False)
# Out:
# county
# Loudoun           213
# Santa Clara        75
# Maricopa           63
# Prince William     63
# Grant              39
#                  ...
# Muskogee            1
# Fairfield           1
# Floyd               1
# Morgan              1
# Wood                1
# Length: 221, dtype: int64

# %%
## which states have the most data centers?
df_datacenters.groupby('state').size().sort_values(ascending=False).head()
# Out:
# state
# Virginia      319
# Texas         127
# California    112
# Oregon        109
# Ohio           93
# dtype: int64

# %%
#saving to 02-processed
df_datacenters.to_csv('data/02-processed/df_datacenters_clean.csv',index=False)
pd.read_csv("data/02-processed/df_datacenters_clean.csv").head()
# Out:
#          id           state      county        sqft
# 0   2744301      New Jersey   Middlesex    105786.0
# 1   9474864  North Carolina    Caldwell   3407194.0
# 2  13924557            Iowa        Polk  11169421.0
# 3  14593270  North Carolina     Catawba   5431080.0
# 4  14930068      New Mexico  Bernalillo    158463.0

# %% [markdown]
# ### Dataset #2: County GDP summary- percent change from preceding period (2022-2024)
#
# https://apps.bea.gov/itable/?ReqID=70&step=1&_gl=1*1fpvxvi*_ga*MTgyMzE3ODI5My4xNzcxNDYxNzcw*_ga_J4698JNNFT*czE3NzE0NjE3NjkkbzEkZzEkdDE3NzE0NjM2NDQkajM5JGwwJGgw#
#
# This dataset was acquired from the US Bureau of Economic Analysis and gives the county Gross Domestic Product (GDP) percent change from preceding period. The period in this case is 2022-2024. This dataset can help us see if there is an economic change from the presence of a data center in any given county. Additionally, since the datapoints are already in percentages, making it easier to compare diverse counties.
#
# Unfortunately, this also means that the data is already fairly aggregated (yearly and county) it is harder to make a precise conclusion. Additionally, there may be additional detail given in the legend/footnote that is hard to incorporate.

# %%
## A. preview of the dataset
df_countygdp = pd.read_csv('data/00-raw/countygdp.csv', skiprows=3)
df_countygdp
# Out:
#                                                 GeoFIPS      GeoName  2022  \
# 0                                                 01001  Autauga, AL   8.4
# 1                                                 01003  Baldwin, AL   6.1
# 2                                                 01005  Barbour, AL  -1.2
# 3                                                 01007     Bibb, AL  -0.4
# 4                                                 01009   Blount, AL   0.8
# ...                                                 ...          ...   ...
# 3133  * Shannon County, SD was renamed to Oglala Lak...          NaN   NaN
# 3134  * Virginia combination areas consist of one or...          NaN   NaN
# 3135  * Estimates for 2024 forward reflect Connectic...          NaN   NaN
# 3136                                (NA) Not available.          NaN   NaN
# 3137    Last updated: February 5, 2026-- new statist...          NaN   NaN
#
#       2023  2024
# 0      1.3  -7.8
# 1      7.6   2.8
# ...

# %%
# B. tidying dataset
state_abb_to_name = {
    'AL':'Alabama', 'AK':'Alaska', 'AZ':'Arizona', 'AR':'Arkansas', 'CA':'California',
    'CO':'Colorado', 'CT':'Connecticut', 'DE':'Delaware', 'FL':'Florida', 'GA':'Georgia',
    'HI':'Hawaii', 'ID':'Idaho', 'IL':'Illinois', 'IN':'Indiana', 'IA':'Iowa',
    'KS':'Kansas', 'KY':'Kentucky', 'LA':'Louisiana', 'ME':'Maine', 'MD':'Maryland',
    'MA':'Massachusetts', 'MI':'Michigan', 'MN':'Minnesota', 'MS':'Mississippi',
    'MO':'Missouri', 'MT':'Montana', 'NE':'Nebraska', 'NV':'Nevada', 'NH':'New Hampshire',
    'NJ':'New Jersey', 'NM':'New Mexico', 'NY':'New York', 'NC':'North Carolina',
    'ND':'North Dakota', 'OH':'Ohio', 'OK':'Oklahoma', 'OR':'Oregon', 'PA':'Pennsylvania',
    'RI':'Rhode Island', 'SC':'South Carolina', 'SD':'South Dakota', 'TN':'Tennessee',
    'TX':'Texas', 'UT':'Utah', 'VT':'Vermont', 'VA':'Virginia', 'WA':'Washington',
    'WV':'West Virginia', 'WI':'Wisconsin', 'WY':'Wyoming'
}

df_countygdp['state_abb'] = df_countygdp['GeoName'].str[-2:]
df_countygdp['state'] = df_countygdp['state_abb'].map(state_abb_to_name)
df_countygdp
# Out:
#                                                 GeoFIPS      GeoName  2022  \
# 0                                                 01001  Autauga, AL   8.4
# 1                                                 01003  Baldwin, AL   6.1
# 2                                                 01005  Barbour, AL  -1.2
# 3                                                 01007     Bibb, AL  -0.4
# 4                                                 01009   Blount, AL   0.8
# ...                                                 ...          ...   ...
# 3133  * Shannon County, SD was renamed to Oglala Lak...          NaN   NaN
# 3134  * Virginia combination areas consist of one or...          NaN   NaN
# 3135  * Estimates for 2024 forward reflect Connectic...          NaN   NaN
# 3136                                (NA) Not available.          NaN   NaN
# 3137    Last updated: February 5, 2026-- new statist...          NaN   NaN
#
#       2023  2024 state_abb    state
# ...

# %%
## B. tidying dataset
df_countygdp.isnull().sum()
# Out:
# GeoFIPS       0
# GeoName      11
# 2022         11
# 2023         11
# 2024         11
# state_abb    11
# state        74
# dtype: int64

# %%
## B. tidying dataset
df_countygdp.tail(11)
# Out:
#                                                 GeoFIPS GeoName 2022 2023  \
# 3127                                   Legend/Footnotes     NaN  NaN  NaN
# 3128  * Estimates from 2008 forward separate Skagway...     NaN  NaN  NaN
# 3129  * Wade Hampton Census Area was renamed Kusilva...     NaN  NaN  NaN
# 3130  * On January 2, 2019, two new county equivalen...     NaN  NaN  NaN
# 3131  * Broomfield County, CO, was created from part...     NaN  NaN  NaN
# 3132  * Kalawao County, Hawaii is combined with Maui...     NaN  NaN  NaN
# 3133  * Shannon County, SD was renamed to Oglala Lak...     NaN  NaN  NaN
# 3134  * Virginia combination areas consist of one or...     NaN  NaN  NaN
# 3135  * Estimates for 2024 forward reflect Connectic...     NaN  NaN  NaN
# 3136                                (NA) Not available.     NaN  NaN  NaN
# 3137    Last updated: February 5, 2026-- new statist...     NaN  NaN  NaN
#
#      2024 state_abb state
# 3127  NaN       NaN   NaN
# ...

# %% [markdown]
# #### Dataset #2 B. tidying dataset
# We can see from the code above that the bottom 11 rows contain null values because it was intended to be a legend/footnote. The legend/footnote contains information about county name changes which are not relevant to our research question. I will now drop these rows.

# %%
df_countygdp = df_countygdp.iloc[:-11]

# %% [markdown]
# #### Dataset #2 B. tidying dataset
# However, based on the information from .info(), there is an issue with the data type. Instead of numeric data, the dataset entries are stored as objects. This prevents us from making calculations. I will convert all the entries into numbers.

# %%
object_columns = ['2022','2023','2024']
df_countygdp[object_columns] = df_countygdp[object_columns].apply(pd.to_numeric,errors='coerce')
df_countygdp.dtypes
# Out:
# /tmp/ipykernel_3219/1580378192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_countygdp[object_columns] = df_countygdp[object_columns].apply(pd.to_numeric,errors='coerce')
# GeoFIPS       object
# GeoName       object
# 2022         float64
# 2023         float64
# 2024         float64
# state_abb     object
# state         object
# dtype: object

# %%
## C. dataset size
df_countygdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3127 entries, 0 to 3126
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GeoFIPS    3127 non-null   object
#  1   GeoName    3127 non-null   object
#  2   2022       3114 non-null   float64
#  3   2023       3114 non-null   float64
#  4   2024       3106 non-null   float64
#  5   state_abb  3127 non-null   object
#  6   state      3064 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 171.1+ KB

# %%
## D. missing data
df_countygdp[df_countygdp.isna().any(axis=1)]
# Out:
#      GeoFIPS                             GeoName  2022  2023  2024 state_abb  \
# 72     02063            Chugach Census Area, AK*   6.7  -6.5 -11.2        K*
# 73     02066       Copper River Census Area, AK*   3.1   7.4   1.2        K*
# 78     02105      Hoonah-Angoon Census Area, AK*  19.0   6.9   2.9        K*
# 81     02130      Ketchikan Gateway Borough, AK*   2.4   7.3   2.6        K*
# 83     02158           Kusilvak Census Area, AK*   2.1  -4.7  -0.9        K*
# ...      ...                                 ...   ...   ...   ...       ...
# 2933   51949         Southampton + Franklin, VA*   2.3  -1.9  -2.8        A*
# 2934   51951  Spotsylvania + Fredericksburg, VA*   2.6   7.0   7.0        A*
# 2935   51953           Washington + Bristol, VA*   1.1   4.3   1.2        A*
# 2936   51955                  Wise + Norton, VA*   9.9  -0.4   3.2        A*
# 2937   51958                York + Poquoson, VA*   3.8  -0.3   5.5        A*
#
#      state
# 72     NaN
# 73     NaN
# ...

# %% [markdown]
# #### Dataset #2 D. missing data
# As we can see, all the missing data relates to the legend that we previously dropped. Referring back, the asterisks refer to changes in the naming/combination of the counties. The only states affected are Alaska and Conneticut which are not relevant to our research question so we will drop all rows containing null values

# %%
## D. missing data
df_countygdp = df_countygdp.dropna()

# %%
## E. outliers

# finding outliers for 2022
Q1 = df_countygdp['2022'].quantile(0.25)
Q3 = df_countygdp['2022'].quantile(0.75)
IQR = Q3 - Q1
outliers_2022 = df_countygdp[(df_countygdp['2022'] < Q1 - 1.5*IQR) | (df_countygdp['2022'] > Q3 + 1.5*IQR)]
print(outliers_2022)
# Out:
#      GeoFIPS                         GeoName  2022  2023  2024 state_abb  \
# 68     02016  Aleutians West Census Area, AK -13.9   1.0  34.9        AK
# 84     02164  Lake and Peninsula Borough, AK -19.1  10.0  18.5        AK
# 87     02185         North Slope Borough, AK -18.2  36.0   8.3        AK
# 106    04011                    Greenlee, AZ -18.6  -7.2  15.2        AZ
# 122    05013                     Calhoun, AR -13.8  -0.6   5.9        AR
# ...      ...                             ...   ...   ...   ...       ...
# 3012   54071                   Pendleton, WV  37.7 -24.6  11.6        WV
# 3029   54105                        Wirt, WV -20.4  17.5  -9.9        WV
# 3031   54109                     Wyoming, WV  26.1   1.9   4.6        WV
# 3117   56027                    Niobrara, WY -13.5  16.1   9.0        WY
# 3121   56035                    Sublette, WY -14.3   3.3  -8.7        WY
#
#               state
# 68           Alaska
# 84           Alaska
# 87           Alaska
# ...

# %% [markdown]
# #### Dataset #2 E. outliers
# I have found the statistical outliers from 2022. However, based on the nature of this dataset, the outliers are not suspicious values. There is natural variability in the gdp of different counties, whether from large companies ceasing operations in the area to natural disaster effects. Thus, it does not make sense at this time to drop these outliers or calculate the outliers for the other years.

# %% [markdown]
# #### Dataset #2 F. cleaning data
# As mentioned above (tidying data), I have removed the missing values from the dataset. As you can see below, the data types are correct (numeric), allowing for calculations. To further clean the dataset, I will drop the GeoFIPS column because it's irrelevant and rename and reformat the datapoints in GeoNames (eg. Autauga, AL -> Autauga). I will change the format to match dataset #1 if we decide to merge these dfs in the future.

# %%
## Dataset #2 F. cleaning data

# dropping stat_ab
df_countygdp = df_countygdp.drop(columns='state_abb')

#removing the state identifier
df_countygdp['GeoName'] = df_countygdp['GeoName'].str[:-4].str.strip()

#renaming geoname to county
df_countygdp = df_countygdp.rename(columns={'GeoName': 'county','2022':'gdp2022','2023':'gdp2023','2024':'gdp2024'})
df_countygdp
# Out:
#      GeoFIPS      county  gdp2022  gdp2023  gdp2024    state
# 0      01001     Autauga      8.4      1.3     -7.8  Alabama
# 1      01003     Baldwin      6.1      7.6      2.8  Alabama
# 2      01005     Barbour     -1.2     -2.4      2.4  Alabama
# 3      01007        Bibb     -0.4      2.8      0.9  Alabama
# 4      01009      Blount      0.8      4.3      8.2  Alabama
# ...      ...         ...      ...      ...      ...      ...
# 3122   56037  Sweetwater     -4.1      4.0     -7.8  Wyoming
# 3123   56039       Teton     -1.8      4.3      2.8  Wyoming
# 3124   56041       Uinta      4.3      0.7      1.4  Wyoming
# 3125   56043    Washakie     -1.2      2.5     -1.3  Wyoming
# 3126   56045      Weston      0.3      3.4      9.9  Wyoming
#
# [3064 rows x 6 columns]

# %%
#saving to 02-processed
df_countygdp.to_csv('data/02-processed/df_countygdp_clean.csv',index=False)
pd.read_csv("data/02-processed/df_countygdp_clean.csv").head()
# Out:
#    GeoFIPS   county  gdp2022  gdp2023  gdp2024    state
# 0     1001  Autauga      8.4      1.3     -7.8  Alabama
# 1     1003  Baldwin      6.1      7.6      2.8  Alabama
# 2     1005  Barbour     -1.2     -2.4      2.4  Alabama
# 3     1007     Bibb     -0.4      2.8      0.9  Alabama
# 4     1009   Blount      0.8      4.3      8.2  Alabama

# %% [markdown]
# ### Dataset #3- CO2 Emissions in U.S created per state from 1970 to 2021
#
# #### Description
#
# ##### Variables
# year: The year for data entry
#
# state-name: Geographical location
#
# sector-name: Economic sector
#
# fuel-name: Fuel type (coal, petroleum, natural gas, and all fuels combined)
#
# value: The amount of emissions in million metric tons of CO2.
#
# The dataset contains annual estimates of CO₂ emissions for each U.S. state from 1970 through 2021. Emissions are disaggregated by state, economic sector, and fuel type, along with the corresponding quantity of CO₂ produced. The economic sectors include industrial, residential, commercial, transportation, and electric power. This sectoral breakdown enables analysis of how emissions sources vary across states and over time. This provides us with plenty of information about CO2 emissions per state, specifically from where the emisions come from and help us find data for the counties that we want to work with.
#
# Every row contains year, state name, one sector that creates CO2 emissions, type of fuel that is used and how much carbon emissions have been created. The listing of about all the states in the U.S. it makes it easier to compare between states or counties when needed. The time frame that this dataset has provides a lot of flexibility to work with a specific period of time, whether is 1 or more years. And the separation the sectors that create CO2 emissions into different categories allows us to identify which sectors are related to A.I. datacenters and which sectors are not. Lastly, the measurements used to estimate the CO2 emissions values per state are "metric tons CO2"(a measure of greenhouse gas mass equal to 1000 kilograms of CO2), one metric ton of CO₂ is roughly equivalent to the emissions from driving a gasoline car about 2,500–2,700 miles. Using this measurement simplifies the analysis by avoiding extremely large numbers with many zeros, making the data easier to interpret and compare.
#
#
# #### 3. Major concerns:
# - The most recent year that this dataset contains is from 2021 which is almsot 5 years ago, not sure if it could be considered old since A.I. was not veyr known at this time.
# - While looking for datasets, I learned that commercial sectors rely a lot on AI datacenters since they are considered a primary engine of the digital economy, making them important to take into consideration when using this dataset.

# %%
import pandas as pd
import numpy as np 
import os

# %%
df_emissions = pd.read_csv("data/00-raw/emissions.csv")

df_emissions.head()
# Out:
#    year state-name                                      sector-name  \
# 0  1970    Alabama              Industrial carbon dioxide emissions
# 1  1970    Alabama              Industrial carbon dioxide emissions
# 2  1970    Alabama              Industrial carbon dioxide emissions
# 3  1970    Alabama              Industrial carbon dioxide emissions
# 4  1970    Alabama  Total carbon dioxide emissions from all sectors
#
#      fuel-name       value
# 0         Coal   26.721507
# 1    Petroleum    3.577779
# 2  Natural Gas    8.944097
# 3    All Fuels   39.243383
# 4    All Fuels  102.646851

# %%
df_emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59901 entries, 0 to 59900
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         59901 non-null  int64
#  1   state-name   59901 non-null  object
#  2   sector-name  59901 non-null  object
#  3   fuel-name    59901 non-null  object
#  4   value        59901 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.3+ MB

# %%
print("Columns:", df_emissions.columns.tolist())
# Out:
# Columns: ['year', 'state-name', 'sector-name', 'fuel-name', 'value']

# %%
print("Shape (rows, columns):", df_emissions.shape)
# Out:
# Shape (rows, columns): (59901, 5)

# %% [markdown]
# This shows there is no missing data in this dataset (no NaN's, no empty cells)

# %%
df_emissions.isna().sum()
# Out:
# year           0
# state-name     0
# sector-name    0
# fuel-name      0
# value          0
# dtype: int64

# %% [markdown]
# Outliers in this dataset

# %%
E1 = df_emissions['value'].quantile(0.25)
E3 = df_emissions['value'].quantile(0.75)
IER = E3 - E1

lower = E1 - 1.5 * IER
upper = E3 + 1.5 * IER

outliers = df_emissions[(df_emissions['value'] < lower) | 
                   (df_emissions["value"] > upper)]

outliers
# Out:
#        year     state-name                                      sector-name  \
# 4      1970        Alabama  Total carbon dioxide emissions from all sectors
# 5      1970        Alabama  Total carbon dioxide emissions from all sectors
# 90     1970     California              Industrial carbon dioxide emissions
# 91     1970     California  Total carbon dioxide emissions from all sectors
# 93     1970     California  Total carbon dioxide emissions from all sectors
# ...     ...            ...                                              ...
# 59841  2021  West Virginia  Total carbon dioxide emissions from all sectors
# 59846  2021  West Virginia          Electric Power carbon dioxide emissions
# 59849  2021  West Virginia          Electric Power carbon dioxide emissions
# 59862  2021      Wisconsin  Total carbon dioxide emissions from all sectors
# 59881  2021        Wyoming  Total carbon dioxide emissions from all sectors
#
#        fuel-name       value
# ...

# %% [markdown]
# #### Summary statistics for dataset

# %%
df_emissions.describe()
# Out:
#                year         value
# count  59901.000000  59901.000000
# mean    1995.101067     35.647050
# std       14.922049    207.883289
# min     1970.000000      0.000022
# 25%     1982.000000      0.793179
# 50%     1995.000000      4.197628
# 75%     2008.000000     19.413459
# max     2021.000000   5996.429314

# %%
df_emissions.groupby("state-name")["value"].mean().sort_values(ascending=False)
# Out:
# state-name
# United States           896.963322
# Texas                   102.763093
# California               63.576063
# Pennsylvania             46.531402
# Ohio                     44.293094
# Illinois                 38.832922
# Louisiana                36.832603
# New York                 36.185886
# Florida                  35.834985
# Indiana                  34.755963
# Michigan                 31.099540
# Georgia                  24.127550
# Kentucky                 21.708451
# North Carolina           21.525167
# Alabama                  20.849465
# New Jersey               20.619025
# Missouri                 20.380596
# Tennessee                18.753383
# West Virginia            17.855781
# Virginia                 17.615618
# Wisconsin                16.261548
# Oklahoma                 16.023834
# Minnesota                14.702458
# Massachusetts            14.286738
# Arizona                  13.191149
# Colorado                 13.045395
# ...

# %%
#saving to 02-processed
df_emissions.to_csv('data/02-processed/df_emissions_clean.csv',index=False)
pd.read_csv("data/02-processed/df_emissions_clean.csv").head()
# Out:
#    year state-name                                      sector-name  \
# 0  1970    Alabama              Industrial carbon dioxide emissions
# 1  1970    Alabama              Industrial carbon dioxide emissions
# 2  1970    Alabama              Industrial carbon dioxide emissions
# 3  1970    Alabama              Industrial carbon dioxide emissions
# 4  1970    Alabama  Total carbon dioxide emissions from all sectors
#
#      fuel-name       value
# 0         Coal   26.721507
# 1    Petroleum    3.577779
# 2  Natural Gas    8.944097
# 3    All Fuels   39.243383
# 4    All Fuels  102.646851

# %% [markdown]
# ### Dataset #4: – USGS County-Level Water Use (2015)
#
# This dataset is located at:
#
# USGS Water Use (County-Level 2015): https://water.usgs.gov/watuse/data/
# (Direct file used in our repo): Google Drive download link (used by get_data.get_raw)
# It contains county-level estimated water withdrawals in the United States for 2015.
# The unit of observation is a county, and the dataset includes multiple categories of water use
# (public supply, irrigation, industrial, thermoelectric, etc.) along with county identifiers. Important variables for this project include county
# and state identifiers and water withdrawal variables such as total withdrawals and sector-specific withdrawals.
# These variables will be used to compare water use in counties hosting data centers versus comparable counties without data centers.
# A limitation is that this dataset is a 5-year USGS release (2015) rather than recent annual data. However, it is the most recent comprehensive
# county-level water use dataset available nationwide and is suitable for baseline comparisons.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This dataset contains county-level estimates of water withdrawals in the United States for 2015, published by the U.S. Geological Survey (USGS). The unit of observation is a county, and the dataset includes total and sector-specific water withdrawals, along with county identifiers such as FIPS codes. We begin by loading the raw dataset from the data/00-raw/ directory and previewing its structure.

# %%
# A) Preview the dataset
df_water = pd.read_csv(
    'data/00-raw/usgs_water_use_county_2015.csv',
    skiprows=1
)
df_water.head()
# Out:
#   STATE  STATEFIPS          COUNTY  COUNTYFIPS  FIPS  YEAR  TP-TotPop  \
# 0    AL          1  Autauga County           1  1001  2015     55.347
# 1    AL          1  Baldwin County           3  1003  2015    203.709
# 2    AL          1  Barbour County           5  1005  2015     26.489
# 3    AL          1     Bibb County           7  1007  2015     22.583
# 4    AL          1   Blount County           9  1009  2015     57.673
#
#   PS-GWPop PS-SWPop  PS-TOPop  ...  TO-WGWTo  TO-WSWFr  TO-WSWSa  TO-WSWTo  \
# 0       --       --    48.998  ...     10.69     45.72       0.0     45.72
# 1       --       --   174.907  ...     73.38     11.32       0.0     11.32
# 2       --       --    24.587  ...      6.06      2.96       0.0      2.96
# 3       --       --    20.947  ...      5.67      0.20       0.0      0.20
# 4       --       --    44.815  ...      4.64     55.43       0.0     55.43
#
#    TO-WFrTo  TO-WSaTo  TO-Wtotl  TO-CUsFrPartial  TO-CUsSaPartial  \
# ...

# %% [markdown]
# We check whether the dataset is already tidy and look at how many rows and columns it has. Each row represents a county, and each column represents a different variable.

# %%
# B) Basic structure / tidy check
df_water.shape, df_water.columns
# Out:
# ((3223, 141),
#  Index(['STATE', 'STATEFIPS', 'COUNTY', 'COUNTYFIPS', 'FIPS', 'YEAR',
#         'TP-TotPop', 'PS-GWPop', 'PS-SWPop', 'PS-TOPop',
#         ...
#         'TO-WGWTo', 'TO-WSWFr', 'TO-WSWSa', 'TO-WSWTo', 'TO-WFrTo', 'TO-WSaTo',
#         'TO-Wtotl', 'TO-CUsFrPartial', 'TO-CUsSaPartial', 'TO-CUTotPartial'],
#        dtype='object', length=141))

# %% [markdown]
# Checking for missing values in the dataset to see where data is missing and how much is missing. This helps us understand whether the missing data might affect our analysis.

# %%
# C) Dataset size and dtypes
print("Number of rows (counties):", df_water.shape[0])
print("Number of columns (variables):", df_water.shape[1])
# Out:
# Number of rows (counties): 3223
# Number of columns (variables): 141

# %% [markdown]
# We examine the distribution of total water withdrawals to see how values are spread out and whether there are any extreme or unusual values.

# %%
# D) Missing values
missing_counts = df_water.isna().sum().sort_values(ascending=False)
missing_counts.head(15)

missing_percent = (df_water.isna().mean() * 100).sort_values(ascending=False)
missing_percent.head(15)
# Out:
# DO-SSPCp    5.895129
# DO-PSPCp    0.124108
# STATE       0.000000
# PO-WSaTo    0.000000
# PT-Wtotl    0.000000
# PT-RecWW    0.000000
# PT-PSDel    0.000000
# PT-CUsFr    0.000000
# PT-CUsSa    0.000000
# PT-CUTot    0.000000
# PT-Power    0.000000
# PO-WGWFr    0.000000
# PO-WGWSa    0.000000
# PO-WGWTo    0.000000
# PO-WSWFr    0.000000
# dtype: float64

# %% [markdown]
# Keeping the columns we need (FIPS and total water withdrawals)

# %%
# Summary statistics for total water withdrawals
df_water['TO-Wtotl'].describe()
# Out:
# count    3223.000000
# mean       99.805172
# std       268.946849
# min         0.000000
# 25%         4.270000
# 50%        13.110000
# 75%        58.010000
# max      3331.360000
# Name: TO-Wtotl, dtype: float64

# %% [markdown]
# Basic summary statistics for total water withdrawls to understand overal patterns

# %%
# Top 10 counties by total water withdrawals

df_water[['STATE', 'COUNTY', 'TO-Wtotl']] \
    .sort_values(by='TO-Wtotl', ascending=False) \
    .head(10)
# Out:
#      STATE              COUNTY  TO-Wtotl
# 1196    MD      Calvert County   3331.36
# 41      AL    Limestone County   2873.04
# 1790    NJ        Salem County   2869.34
# 1949    NC  Mecklenburg County   2785.62
# 2279    PA    Lancaster County   2615.90
# 2352    SC       Oconee County   2607.53
# 1157    LA  St. Charles Parish   2398.14
# 1887    NY  Westchester County   2189.34
# 1241    MI      Berrien County   2125.76
# 313     CT   New London County   2111.04

# %%
# removing County from COUNTY column
df_water['COUNTY'] = df_water['COUNTY'].str.replace('County', '', regex=False)

#dropping STATE, STATEFIPS


#renaming all caps columns
df_water = df_water.rename(columns={
    'STATE': 'state',
    'COUNTY': 'county'
})

# %%
# changing from state abb to state name

df_water['state'] = df_water['state'].map(state_abb_to_name)

# %%
#saving to 02-processed
df_water.to_csv('data/02-processed/df_water_clean.csv',index=False)
pd.read_csv("data/02-processed/df_water_clean.csv").head()
# Out:
#      state  STATEFIPS    county  COUNTYFIPS  FIPS  YEAR  TP-TotPop PS-GWPop  \
# 0  Alabama          1  Autauga            1  1001  2015     55.347       --
# 1  Alabama          1  Baldwin            3  1003  2015    203.709       --
# 2  Alabama          1  Barbour            5  1005  2015     26.489       --
# 3  Alabama          1     Bibb            7  1007  2015     22.583       --
# 4  Alabama          1   Blount            9  1009  2015     57.673       --
#
#   PS-SWPop  PS-TOPop  ...  TO-WGWTo  TO-WSWFr  TO-WSWSa  TO-WSWTo  TO-WFrTo  \
# 0       --    48.998  ...     10.69     45.72       0.0     45.72     56.41
# 1       --   174.907  ...     73.38     11.32       0.0     11.32     84.70
# 2       --    24.587  ...      6.06      2.96       0.0      2.96      9.02
# 3       --    20.947  ...      5.67      0.20       0.0      0.20      5.87
# 4       --    44.815  ...      4.64     55.43       0.0     55.43     60.07
#
# ...

# %% [markdown]
# ### Dataset #5: Average Retail Price of Electricity (U.S., State-Level)
#
# This dataset comes from the U.S. Energy Information Administration (EIA) and reports the average retail price of electricity in cents per kilowatt-hour across U.S. states over time. Key variables include time (monthly), geographic location (state), end-sector (commercial), and electricity price. This dataset can be used to analyze trends in electricity costs and regional differences in energy prices. A major limiation is that the prices are reported at the state level rather than the county level, which may cover up localized variation in electricity costs near large data centers. While county level electricity data is not consistently available nationwide, state-level prices provide a useful approximation for comparing electricity cost differences across regions.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA DOES HERE 
#import the pandas library which is used for data loading and manipulation
import pandas as pd

# Load the electricity prices dataset from the raw data folder
#skiprows=4 skips the metadata rows at the top of the CSV file
#header = 0 tells pandas that the first row after skipping is the column names 
df_electricity = pd.read_csv("data/00-raw/electricity_price_state.csv", skiprows = 4, header = 0)

#Display the first 5 rows of the dataset to confirm it loaded correctly
df_electricity.head()
# Out:
#                            description                   units  \
# 0  Average retail price of electricity  cents per kilowatthour
# 1                          All sectors                     NaN
# 2                           Commercial  cents per kilowatthour
# 3           Commercial : United States  cents per kilowatthour
# 4             Commercial : New England  cents per kilowatthour
#
#              source key  Jan 2001  Feb 2001  Mar 2001  Apr 2001  May 2001  \
# 0                   NaN       NaN       NaN       NaN       NaN       NaN
# 1   ELEC.PRICE.US-ALL.M       NaN       NaN       NaN       NaN       NaN
# 2   ELEC.PRICE.US-COM.M       NaN       NaN       NaN       NaN       NaN
# 3   ELEC.PRICE.US-COM.M      7.25      7.51      7.70      7.73      7.77
# 4  ELEC.PRICE.NEW-COM.M     10.30     10.44     10.54     10.85     10.74
#
#    Jun 2001  Jul 2001  ...  Feb 2025  Mar 2025  Apr 2025  May 2025  Jun 2025  \
# ...

# %%
# Show the size of the dataset (rows, columns)
df_electricity.shape
# Out:
# (65, 302)

# %% [markdown]
# **Dataset Structure:**
# This dataset is currently in a wide format, where each column represents a different month and year. For later analysis, the data will likely need to be reshaped into a long tidy format with separate columns for date and electricity prices.

# %%
#Check missing values across columns 
df_electricity.isna().sum().head(10)
# Out:
# description    0
# units          1
# source key     1
# Jan 2001       3
# Feb 2001       3
# Mar 2001       3
# Apr 2001       3
# May 2001       3
# Jun 2001       3
# Jul 2001       3
# dtype: int64

# %%
df_electricity = df_electricity.dropna()
df_electricity = df_electricity.drop(columns=['source key'])
cols_modern = [col for col in df_electricity.columns if '2021' in col or '2022' in col or '2023' in col or '2024' in col or '2025' in col or col in ['description','units']]
df_electricity = df_electricity[cols_modern]
df_electricity
# Out:
#                            description                   units  Jan 2021  \
# 3           Commercial : United States  cents per kilowatthour     10.27
# 4             Commercial : New England  cents per kilowatthour     15.86
# 5             Commercial : Connecticut  cents per kilowatthour     16.25
# 6                   Commercial : Maine  cents per kilowatthour     12.76
# 7           Commercial : Massachusetts  cents per kilowatthour     16.15
# ..                                 ...                     ...       ...
# 60                 Commercial : Oregon  cents per kilowatthour      8.98
# 61             Commercial : Washington  cents per kilowatthour      8.91
# 62  Commercial : Pacific Noncontiguous  cents per kilowatthour     23.76
# 63                 Commercial : Alaska  cents per kilowatthour     18.67
# 64                 Commercial : Hawaii  cents per kilowatthour     29.05
#
#     Feb 2021  Mar 2021  Apr 2021  May 2021  Jun 2021  Jul 2021  Aug 2021  ...  \
# ...

# %%
# editing format of description column
df_electricity['description'] = df_electricity['description'].str[12:].str.strip()

# %%
df_electricity.rename(columns={'description':'state'}, inplace=True)
df_electricity['state'].unique()
# Out:
# array(['United States', 'New England', 'Connecticut', 'Maine',
#        'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont',
#        'Middle Atlantic', 'New Jersey', 'New York', 'Pennsylvania',
#        'East North Central', 'Illinois', 'Indiana', 'Michigan', 'Ohio',
#        'Wisconsin', 'West North Central', 'Iowa', 'Kansas', 'Minnesota',
#        'Missouri', 'Nebraska', 'North Dakota', 'South Dakota',
#        'South Atlantic', 'Delaware', 'District Of Columbia', 'Florida',
#        'Georgia', 'Maryland', 'North Carolina', 'South Carolina',
#        'Virginia', 'West Virginia', 'East South Central', 'Alabama',
#        'Kentucky', 'Mississippi', 'Tennessee', 'West South Central',
#        'Arkansas', 'Louisiana', 'Oklahoma', 'Texas', 'Mountain',
#        'Arizona', 'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico',
#        'Utah', 'Wyoming', 'Pacific Contiguous', 'California', 'Oregon',
#        'Washington', 'Pacific Noncontiguous', 'Alaska', 'Hawaii'],
# ...

# %%
rows_to_drop = ['United States', 
                             'New England', 
                             'Middle Atlantic',
                             'East North Central',
                             'West North Central',
                             'East South Central',
                             'West South Central',
                             'Mountain',
                             'Pacific Contiguous',
                             'Pacific Noncontiguous',
                             'South Atlantic']
df_electricity = df_electricity[~df_electricity['state'].isin(rows_to_drop)].reset_index()
df_electricity
# Out:
#     index                 state                   units  Jan 2021  Feb 2021  \
# 0       5           Connecticut  cents per kilowatthour     16.25     17.07
# 1       6                 Maine  cents per kilowatthour     12.76     12.85
# 2       7         Massachusetts  cents per kilowatthour     16.15     16.72
# 3       8         New Hampshire  cents per kilowatthour     15.34     16.54
# 4       9          Rhode Island  cents per kilowatthour     16.60     16.81
# 5      10               Vermont  cents per kilowatthour     15.89     16.08
# 6      12            New Jersey  cents per kilowatthour     12.23     12.03
# 7      13              New York  cents per kilowatthour     14.08     15.15
# 8      14          Pennsylvania  cents per kilowatthour      8.25      8.53
# 9      16              Illinois  cents per kilowatthour      8.93      9.36
# 10     17               Indiana  cents per kilowatthour     11.10     11.41
# ...

# %% [markdown]
# **Missing Data:**
# The dataset contains a small number of missing values across several columns. The "description" column has no missing values, while the "units" and "source key" columns each contain one missing entry. Monthly price columns contain three missing values each, which likely corresponds to non-state rows like aggregate or metadata entires instead of the actual state level observations. This pattern suggest that missing of values is systematic and related to how the dataset is structured, not due to random data loss.

# %%
#saving to 02-processed
df_electricity.to_csv('data/02-processed/df_electricity_clean.csv',index=False)
pd.read_csv("data/02-processed/df_electricity_clean.csv").head()
# Out:
#    index          state                   units  Jan 2021  Feb 2021  Mar 2021  \
# 0      5    Connecticut  cents per kilowatthour     16.25     17.07     16.82
# 1      6          Maine  cents per kilowatthour     12.76     12.85     12.52
# 2      7  Massachusetts  cents per kilowatthour     16.15     16.72     16.67
# 3      8  New Hampshire  cents per kilowatthour     15.34     16.54     15.98
# 4      9   Rhode Island  cents per kilowatthour     16.60     16.81     16.13
#
#    Apr 2021  May 2021  Jun 2021  Jul 2021  ...  Feb 2025  Mar 2025  Apr 2025  \
# 0     16.73     16.01     16.04     17.33  ...     25.86     25.17     24.40
# 1     12.28     12.53     12.38     12.42  ...     20.17     21.74     21.35
# 2     15.70     16.02     16.79     17.74  ...     23.89     23.12     22.83
# 3     16.62     15.87     16.11     16.13  ...     20.78     19.72     19.48
# 4     15.15     14.51     14.92     14.97  ...     26.43     24.52     23.80
#
# ...

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# In analyzing factors such as CO₂ emissions and electricity use, we recognize that environmental conditions in certain areas may be influenced by geographic location, climate, or existing infrastructure rather than being solely attributable to data center resource usage. To address this potential collection bias, we remain mindful of external and contextual factors that could skew interpretations of the data and acknowledge these limitations when drawing conclusions.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#        Though we are analyzing factors such as CO₂ emissions and electricity use, the environmental impacts in a certain area could be in worse conditions due to location rather than being simply a result of data center resource usage.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#        By potentially generalizing information to county-specific and not including individual’s data, the exposure of PII would be minimized.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#        All the information that we plan to use from datasets would be from publicly available databases, so no confidential and secure data could be potentially compromised.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#        A stakeholder’s perspective that may need to be considered are those of the team behind the data centers (who are subject matter experts), explaining the outcomes and necessary parts that go into powering data centers. This missing perspective may provide crucial insight and context into whatever we analyze from the data to answer our research question.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#     Same as mentioned previously, analyzing factors such as CO₂ emissions and electricity use, their specific environmental impacts in a certain area could be resulting in more concerning data due to location rather than being simply a result of data center resource usage (which could be omitted confounding variables).
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#     This project doesn't require us to be building or deploying a predictive model, just addressing ethical concerns related to how our data analysis/results can be potentially interpreted. Environmental and economic conditions differ immensely from county to county, so certain patterns within the data could be mistaken as simple cause-and-effect relationships when they are actually just correlations. There is also a risk these countries which are hosting AI data centers could be judged unfairly if differences in their specific infrastructure, climate, or local government policies are not taken into account.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#     To address these concerns previously listed, our team will be very diligent in explaining our limitations of the analysis and avoiding making causal claims without a strong reason to do so. We will present our results with appropriate context and acknowledge uncertainty in the data. By framing our conclusions carefully and avoiding generalizations, we aim to reduce the risk of our findings being misinterpreted.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Proficient

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/02  |  5 PM zoom | Brainstorm project ideas and potential datasets  | Review potential project ideas and finalize. Assign sections of project proposal |
# | 2/04 |  Before 11:59 PM |  NA | Turn in project proposal |
# | 2/11  | 5 PM  | Find at least one new potential dataset  |  Choose best datasets and assign sections of data checkpoint. Start wrangling data   |
# | 2/18  | Before 11:59 PM  | NA | Submit data checkpoint   |
# | 2/21  | 5 PM | NA | Review as a team steps for enhancing collaboration in future, current issues, etc |
# | 2/25  | 5 PM  | Review data checkpoint feedback | Revise datasets if needed, EDA discussion, assign sections of EDA checkpoint |
# | 3/04  | Before 11:59 PM  |  NA | Submit EDA checkpoint |
# | 3/11  | 5 PM  | Final project report. At least one note about potential modification | If anything needs to be modified. Finalize and submit project. Discuss video logistics |
# | 3/15  | 5 PM  |  Video logistics | Film video |
# | 3/18  | Before 11:59 PM  |  NA | Submit video and final project and team evaluation survey |
