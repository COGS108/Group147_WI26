# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors
#
# - Athena Vimal:
# - Lucy Pan: Conceptualization, Data curation, Writing – original draft, Writing – review & editing, Project administration
# - Kimberly Haro: Background research, conceptualization, Writing – original draft, Writing – review & editing, Analysis- Regression analysis (economic and environmental) & result interpretation.
# - Ruth Mazariego: Research Question, Hypothesis, Writing – review & editing, treatmennt variables, troubleshooting, and Environmental EDA matching style (CO emissions, water and electricity)
# - Duglas Zacarias:

# %% [markdown]
# ## Research Question

# %% [markdown]
# How do U.S. counties hosting large-scale data centers differ from comparable non-host counties in terms of economic outcomes (GDP) and environmental impacts (CO₂ emissions, water and electricity use)?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Technology has been invented in order to make human lives easier, but as this technology keeps evolving, the world starts changing too. With the invention of artificial intelligence (AI), many controversies have come up when it comes to the benefits and disadvantages that it brings to the environment, the economy, education, and our everyday life. Some studies suggest that AI can support environmental sustainability by improving efficiency, energy systems and allow better monitoring of environmental conditions[1](#cite_ref-1) [2](##cite_ref-2). At the same time, the fast expansion of AI has created new forms of resource demand that raise sustainability concerns. As AI data centers increase across economic sections, understanding both its potential benefits and environmental consequences has become very important.
#
# AI systems rely on very large computer infrastructure that is mainly located in data centers in order to support tasks such as cloud computing, machine learning training, and large data processing. Reviews of data center operations indicate that energy intensive servers and cooling systems make these facilities among the fastest growing sources of industrial electricity consumption worldwide. [3](#cite_ref-3) In the United States, the growth of AI has contributed to a fast expansion of data centers infrastructure, increasing overall demand for electricity and placing tension on power systems.[4](#cite_ref-4) As AI continues to grow, the physical infrastructure needed to support these technologies has become a main factor in looking at sustainability.
#
# Studies demonstrate that data centers contribute to a significant and growing environmental burden in the AI era. Guidi et al, find that U.S. data centers consume a major portion of national electricity and that AI data centers are only increasing this. Large chunks of data centers can put tension on regional power grids, increase peak demand, and sometimes prolong dependency on carbon intensive energy sources.[5](#cite_ref-5) In addition to energy consumption, water usage for cooling is a major concern, especially in dry regions. Although solutions like advanced cooling systems, waste heat reuse, and water positive designs have been proposed, their adoption remains inconsistent across facilities.[6](#cite_ref-6) Together, these studies show that AI data centers generate major environmental impacts related to electricity demand, greenhouse emissions, and water consumption.
#
# In addition to environmental concerns, data centers are often promoted as an economic growth impact in host communities. Research indicates that regulatory environments can increase data center valuation, and attract private investment, encouraging companies to locate large facilities in certain regions.[7](#cite_ref-7) Data centers may also contribute to local tax revenue infrastructure development and employment opportunities, particularly in technology and engineering sections.[8](#cite_ref-8) However, community research suggests that these economic benefits are often going along with local costs, including increased demand for electricity and water, land use pressure, and environmental stress.[9](#cite_ref-9) While prior work studies have examined economic outcomes or environmental impacts separately, only a few directly compare these topics at the county level across the United States. The lack of research motivates a modified evaluation of how U.S. counties hosting large-scale data centers differ from comparable non-hosting counties in terms of environmental impacts (CO2 emissions, electricity use, and water consumption) and economic outcomes (employment growth and municipal tax revenue).
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Oluwaseun, A. Analyzing How AI Impacts Environmental Sustainability: A Case Study for the USA.
# https://doi.org/10.21203/rs.3.rs-5953542/v1
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Kirikkaleli, D., et al. Environmental Sustainability in the USA: Role of Artificial Intelligence. Sustainable Futures.
# https://doi.org/10.1016/j.sftr.2025.100823
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3)Raphael, D., et al. Impact of Data Centers on Climate Change: A Review of Energy Efficient Strategies.
# https://www.researchgate.net/profile/Ochuko-Orikpete/publication/373295068_Impact_of_Data_Centers_on_Climate_Change_A_Review_of_Energy_Efficient_Strategies/links/64e505820453074fbda78c3f/Impact-of-Data-Centers-on-Climate-Change-A-Review-of-Energy-Efficient-Strategies.pdf
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4)Guidi, G., et al. Environmental Burden of United States Data Centers in the Artificial Intelligence Era.
# https://arxiv.org/pdf/2411.09786
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5)Chen, X., et al. Electricity Demand and Grid Impacts of AI Data Centers: Challenges and Prospects.
# https://arxiv.org/pdf/2509.07218
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6)Díaz-Marín, C. D., & Berquist, Z. J. Flipping the Switch: Carbon-Negative and Water-Positive Data Centers Through Waste Heat Utilization.
# https://pubs.rsc.org/en/content/articlelanding/2025/ee/d5ee02676h
# 7. <a name="cite_note-7"></a> [^](#cite_ref-7)Lee, D. Impact of Environmental Regulation on Data Center Valuation. MIT Master’s Thesis.
# https://dspace.mit.edu/bitstream/handle/1721.1/158830/Lee-dhlee23-msred-cre-2025-Thesis.pdf?sequence=1&isAllowed=y
# 8. <a name="cite_note-8"></a> [^](#cite_ref-8)Berger, A. Artificial Intelligence Data Centers and United States-Based Hyperscalers: Impacts and Solutions.
# https://jscholarship.library.jhu.edu/items/8792d5a5-91a3-4179-bc73-61fcc2ae187
# 9. <a name="cite_note-9"></a> [^](#cite_ref-9)Ngata, W., et al. The Cloud Next Door: Investigating the Environmental and Socioeconomic Strain of Datacenters on Local Communities.
# https://dl.acm.org/doi/10.1145/3715335.3736324

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that counties hosting large-scale data centers will experience higher CO₂ emissions, water electricity usage, but also higher GDP, compared to comparable counties without data centers.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# ##### Dataset #1
#   - Dataset Name: Data Centers in the US
#   - Link to the dataset: https://data.msdlive.org/records/65g71-a4731
#   - Number of observations: 1479
#   - Number of variables: 13
#   - Description of the variables most relevant to this project:
# <br> state: The state where the data center is
# <br> county: The county where the data center is
# <br> sqft: The area in square feet of the data center
#   - Descriptions of any shortcomings this dataset has with respect to the project
# <br> Doesn't contain the date in which the data center was opened.
#
# ##### Dataset #2
#   - Dataset Name: County GDP summary- percent change from preceding period
#   - Link to the dataset: https://apps.bea.gov/itable/?ReqID=70&step=1&_gl=1*1fpvxvi*_ga*MTgyMzE3ODI5My4xNzcxNDYxNzcw*_ga_J4698JNNFT*czE3NzE0NjE3NjkkbzEkZzEkdDE3NzE0NjM2NDQkajM5JGwwJGgw#
#   - Number of observations: 3138
#   - Number of variables: 5
#   - Description of the variables most relevant to this project
# <br> GeoName: The county name with the related state abbreviation
# <br> 2022: The percent change in county GDP from 2021
# <br> 2023: The percent change in county GDP from 2022
# <br> 2024: The percent change in county GDP from 2024
#   - Descriptions of any shortcomings this dataset has with respect to the project
# <br>
# High level of aggregation thus missing out on variability.
# ##### Dataset #3
#   - Dataset Name: CO2 emission (in U.S)
#   - Link to the dataset: https://www.kaggle.com/datasets/alistairking/u-s-co2-emissions
#   - Number of observations: 59901
#   - Number of variables: 5
#   - Description of the variables most relevant to this project
#         Sector name: This could allow us to use certain sectors where AI datacenters are located.
#         Value: Amount of emissions in million metric tons of CO2.
#         Year: It would help us compare how the increased use of AI influenced the amount of CO2 emissions created.
#   - Descriptions of any shortcomings this dataset has with repsect to the project:
#       - The dataset contains a lot information about the many sectors that create carbon dioxide emissions, but I believe that we should be able to filter the data to only focus on the “Industrial carbon dioxide emission” or A.I. datacenter related sectors in the US.
#       - Not sure if the measurement used for CO2 emission would be a problem in the future.
#       - The last data year entry was in 2021 which may or many not be considered recent.
#   - Ideas: This dataset could be used to calculate environmental costs since is one of the environmental damages that datacenters do. And it would also help to calculate in total how much CO2 do counties in a state produce or to compare between states hosting and not hosting A.I. datacenters.
#
# ##### Dataset #4
#   - Dataset Name: USGS Estimated Use of Water in the United States — County-Level Data (2015)
#   - Source: https://water.usgs.gov/watuse/data/
#   - Geographic Level: County
#   - Time Period: 2015
#   - Number of Observations: ~3,000 counties
#   - Key Variables: Total water withdrawals (Mgal/day), Public supply, Industrial, Thermoelectric power
#   - Limitations: Reported every 5 years rather than annually.
#
#
# ##### Dataset #5
# - Dataset Name: Average Retail Price of Electricity (state level)
# - Link to dataset: https://www.eia.gov/electricity/data/browser/#/topic/7?agg=1,0&geo=vvvvvvvvvvvvo&endsec=4&freq=M&start=200101&end=202511&ctype=linechart&ltype=pin&rtype=s&pin=&rse=0&maptype=0
# - Source: U.S. Energy Information Administration (EIA)
# - Geographic level: State
# - Time period January 2001-November 2025 (monthly data)
# - Number of observations: 65 rows (states, regions, and national aggregates)
# - Number of variables: ~302 variables (description, units, source key, monthly price columns)
# - Key variables: decription (identifies the geographic area and sector), units (electricity price measured in cents per kilowatt-hour), source key (EIA series identifier), and monthly price columns (Jan 2001-Nov 2025, average reatail electricity prices per each month).
# - Description of variables most relevant: This dataset provides average residential electricity prices by U.S. state over time, measured in cents per kilowatt-hour. The data captures monthly price variation across states, allowing comparisons of electricity cost trends over time and across regions.
# - Limitations: A key limitation of this dataset is that electricity prices are reported at the state level rather than the county level. The data can't capture within state variation in electricity prices, which limits its ability to specifically align with county level data on data center locations. Also, state level averages may cover local price differences that could be relevant when analyzing the impacts of invidual data centers. Despite this limitation, state level electricity prices still provide useful information when comparing broarder cost patterns that are associated with data center activity.

# %% [markdown]
# ### Dataset #1- Data Centers in the US
# To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis

# %%
import pandas as pd
# main dataset
df_dc = pd.read_csv("data/02-processed/df_datacenters_clean.csv")
df_dc.head()

# %%
#total sqft derived from this dataset
df_total_sqft = pd.read_csv("data/02-processed/total_sqft.csv")
df_total_sqft.head()

# %% [markdown]
# ### Dataset #2- County GDP summary- percent change from preceding period

# %%
df_countygdp = pd.read_csv("data/02-processed/df_countygdp_clean.csv")
df_countygdp.head()

# %% [markdown]
# ### Dataset #3- CO2 emission (in U.S)

# %%
df_emissions = pd.read_csv("data/02-processed/df_emissions_clean.csv")

#cleaner, smaller df (df_co2)
df_co2 = df_emissions[(df_emissions['sector-name']=='Industrial carbon dioxide emissions') & (df_emissions['year']==2021) & (df_emissions['fuel-name'] == 'All Fuels')]
df_co2 = df_co2.rename(columns={
    'state-name': 'state',
})
df_co2.head()

# %% [markdown]
# ### Dataset #4- USGS Estimated Use of Water in the United States — County-Level Data (2015)

# %%
df_water = pd.read_csv("data/02-processed/df_water_clean.csv")
df_water.head()

# %% [markdown]
# ### Dataset #5- Average Retail Price of Electricity (state level)

# %%
df_electricity = pd.read_csv("data/02-processed/df_electricity_clean.csv")
df_electricity.head()

# %% [markdown]
# ### Dataset #6 - Final merged dataset

# %%
df = pd.read_csv("data/02-processed/df.csv")

# %%
# creating treatment variables

# has_dc: 1 if county has a data center, 0 otherwise
df['has_dc'] = df['total_sqft'].apply(lambda x: 1 if x > 0 else 0)

# large_dc if sqft over 1,000,000, 1 if yes, 0 otherwise
df['large_dc'] = df['total_sqft'].apply(lambda x: 1 if x > 1_000_000 else 0)

df['large_dc']

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your EDA feedback
#
# **NOTE** The final report should not be overly long.  If this EDA step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any EDA you later decided was unecessary side quest.
# 2) if the code to EDA is very long (in either lines or in time to compute) make sure you write out images of the EDA into `results/` and reload them as images here instead of recalculating it. And make a statement here like "To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`."

# %% [markdown]
# ### Section 1 of EDA - Economic Analysis
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model
#
# **NOTE** The final report should not be overly long.  If this analysis step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any analysis you later decided was unecessary side quest before checking in for the final hand in
# 2) if the code to do an analysis is very long (in either lines or in time to compute) put it in a different file.  In that file make write out results of analysis into `results/` and reload the results here instead of recalculating it. And make a statement here like "To see the code responsible for analyses see `path/to/some-file-name.ipynb_or.py`."

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Number of counties ( by state) with data centers
dc_by_state = df.groupby("state")["has_dc"].sum().sort_values(ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(x=dc_by_state.index, y=dc_by_state.values)
plt.xticks(rotation=45)
plt.title("Number of Counties with Data Centers by State")
plt.xlabel("State")
plt.ylabel("Count of Counties with Data Centers")
plt.show()

# %%
# Share of counties (by state) with data centers 
dc_share_state = df.groupby("state")["has_dc"].mean().sort_values(ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(x=dc_share_state.index, y=dc_share_state.values)
plt.xticks(rotation=45)
plt.title("Share of Counties with Data Centers by State")
plt.xlabel("State")
plt.ylabel("Share of Counties with Data Centers")
plt.show()

# %%
# Data center size distribution
plt.figure(figsize=(7,5))
sns.histplot(df["total_sqft"], bins=40)
plt.title("Distribution of Data Center Square Footage")
plt.xlabel("Total Data Center Square Footage")
plt.ylabel("Count")
plt.show()

# %%
# Log-scaled version 
plt.figure(figsize=(7,5))
sns.histplot(np.log1p(df["total_sqft"]), bins=40)
plt.title("Log Distribution of Data Center Square Footage")
plt.xlabel("Log(Total Sqft + 1)")
plt.ylabel("Count")
plt.show()

# %%
def plot_variable_relationship(data, variable, title):

    plt.figure(figsize=(6,5))
    sns.boxplot(data=data, x="has_dc", y=variable)

    plt.title(title)
    plt.xlabel("Data Center Presence (0 = No, 1 = Yes)")
    plt.ylabel(variable)

    plt.show()

    print("\nMean values:")
    print(data.groupby("has_dc")[variable].mean())

# %%
# GDP Analysis
print("\n----- GDP Analysis -----")

plot_variable_relationship(
    df,
    "gdp2022",
    "Baseline GDP Growth (2022) by Data Center Presence"
)

plot_variable_relationship(
    df,
    "gdp2023",
    "GDP Growth (2023) by Data Center Presence"
)

plot_variable_relationship(
    df,
    "gdp2024",
    "GDP Growth (2024) by Data Center Presence"
)


# GDP Trend visualizations
gdp_cols = ["gdp2022","gdp2023","gdp2024"]

gdp_means = df.groupby("has_dc")[gdp_cols].mean().T

plt.figure(figsize=(7,5))

plt.plot(gdp_means.index, gdp_means[0], marker="o", label="No Data Center")
plt.plot(gdp_means.index, gdp_means[1], marker="o", label="Has Data Center")

plt.title("Average GDP Growth Trend by Data Center Presence")
plt.xlabel("Year")
plt.ylabel("Average GDP Growth (%)")
plt.legend()

plt.show()

# %%
# Electricity Price Analysis

plot_variable_relationship(
    df,
    "elec_price_2021",
    "Electricity Price by Data Center Presence"
)

plt.figure(figsize=(6,5))

sns.scatterplot(
    data=df,
    x="elec_price_2021",
    y="total_sqft",
    hue="has_dc"
)

plt.title("Electricity Price vs Data Center Size")
plt.xlabel("Electricity Price")
plt.ylabel("Total Data Center Square Footage")

plt.show()

# %% [markdown]
# ### Section 2 of EDA - Environmental Analysis
#
# This part compares the state-level CO2 emissons (per capita) and water usage (industrial per capita). It produced visualizations to better understand trends and differences between states.

# %%
#Prepare a dataset for regression 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# First, we would identify the counties with data centers and without datecenters.
#
# 1 = Number of counties that host data center(s)
#
# 0 = Number county does not host data center(s)

# %%
#Gets rid of the top 1% of the outliers for data can be fair (explain below)
df['host_county'] = (df['total_sqft'] > 0).astype(int)

# %%
#Cretes visualization does the numbers
county_counts = df['host_county'].value_counts().rename({
    0: "No Data Center",
    1: "Has Data Center"
})

print(county_counts)

plt.figure(figsize=(6,4))

sns.countplot(data=df, x='host_county')

plt.xticks([0,1], ['No Data Center','Has Data Center'])
plt.title("Number of Counties With vs Without Data Centers")
plt.xlabel("County Type")
plt.ylabel("Number of Counties")

plt.show()

# %% [markdown]
# As shown in the visual above, data centers are geographically concentrated. Only a small fraction of counties in the U.S. host large-scale data centers which indicates that the environmental impacts of data centers are geohgraphically concentrated rather than evenly distributed. Because of how data centers tend to be geographically concentrated which would affect how the graphs look like when comparing, we would be dropping the top 1% of values. This would make the analysis more fair to what we are trying to answer.

# %%
# 1. Create derived columns
# CO2 per capita (if TP-TotPop exists)
if 'TP-TotPop' in df.columns:
    df['co2_per_capita'] = df['value'] / df['TP-TotPop']
else:
    df['co2_per_capita'] = df['value']  # fallback if no population column

# CO2 per GDP
df['co2_per_gdp'] = df['value'] / df['gdp2022'] 

# Water withdrawals per capita (using TO-Wtotl)
df['water_per_capita'] = df['TO-Wtotl'] / df['TP-TotPop'] if 'TP-TotPop' in df.columns else df['TO-Wtotl']

# %%
# Eliminating the top 1% of counties that are outliers 
plot_df = df[
    (df['water_per_capita'] <= df['water_per_capita'].quantile(0.99)) &
    (df['co2_per_capita'] <= df['co2_per_capita'].quantile(0.99))
]

# %% [markdown]
# #### Comparing host vs non-host counties CO2 emissions

# %%
# Visualization for CO2 Emissions 
plt.figure(figsize=(6,5))
sns.boxplot(data=plot_df, x='host_county', y='co2_per_capita')

#Names for title and axis of boxplots 
plt.xticks([0,1], ['No Data Center','Has Data Center'])
plt.title("CO₂ Emissions per Capita: Host vs Non-Host Counties")
plt.ylabel("CO₂ per Capita")

#Uses log scale because data is extremely skewed
plt.yscale('log')

plt.show()

# %% [markdown]
# #### Water usage

# %%
# Boxplot visualization for water usage
plt.figure(figsize=(6,5))
sns.boxplot(data=plot_df, x='host_county', y='water_per_capita')

# Names for title and axis of boxplots 
plt.xticks([0,1], ['No Data Center','Has Data Center'])
plt.title("Water Use per Capita: Host vs Non-Host Counties")
plt.ylabel("Water per Capita")

#Uses log scale because data is extremely skewed
plt.yscale('log')  

plt.show()

# %% [markdown]
# #### Electricity Usage

# %%
plt.figure(figsize=(6,5))
sns.boxplot(data=df, x='host_county', y='elec_price_2021')

plt.xticks([0,1], ['No Data Center','Has Data Center'])
plt.title("Electricity Price: Host vs Non-Host Counties")
plt.ylabel("Electricity Price")

plt.show()

# %% [markdown]
# #### Average Differences

# %%
# Calculating the mean for CO2 emissions, water usage and electrivity usage
df.groupby('host_county')[[
    'co2_per_capita',
    'water_per_capita',
    'elec_price_2021'
]].mean()

# %%
# Calculating the median for CO2 emissions, water usage and electrivity usage
df.groupby('host_county')[[
    'co2_per_capita',
    'water_per_capita',
    'elec_price_2021'
]].median()

# %% [markdown]
# #### Interpretation of Results
#
# By looking at the mean results, we could say that counties without datacenters have higher numbers when it comes to CO2 emissions and wanter usage per capita, while electricity prices are similar between the two groups. However, only 217 counties host-large scale data centers while 2847 counties do not, this imbalance reflects the geographical concentration of data centers mentined before. Thus, non-host counties group contains several extreme outliers which inflate mean values for CO2 emissions and water usage.
#
# Median compariosn provide a clearer view of the typical county and show that relativaly similar environmental costs between host and non-host counties. This makes clean that simple descriptive comparisons may not fully capture the casual relatioshop between data centers and environmental costs and that other accounting factors for the environmental costs.

# %% [markdown]
# # Section 3 of EDA- Regression Analysis
#
# In this section, we run simple OLS (ordinary least squares) regression models using has_dc (a binary indicator for whether a county hosts at least one data center) as the main explanatory variable. We focus on economic outcomes using county GDP (2022-2024) and environmental outcomes using CO2 emissions and electricity price. Because CO2 and electricity price measures are available at the state level in the datasets we currently have, we interpret environmental regressions as broarder association and avoid making strong county-level claims. This regression analysis aligns with oour hypothesis that host locations may experience both economic gains and environmental costs

# %%
#Prepare a dataset for regression 
import statsmodels.formula.api as smf

# %%
# list of the variables needed for the regression models
# Columns we need for the regressions in this section
# NOTE: CO2 is currently stored in the column named "value"
needed_cols = ["has_dc", "gdp2022", "gdp2023", "gdp2024", "value", "elec_price_2021"]

# Check if any needed columns are missing
missing = [col for col in needed_cols if col not in df.columns]

if len(missing) > 0:
    print("Missing columns in df:", missing)
    print("Fix: Run the earlier merge/cleaning cells that create df, then run this section again.")
else:
    # Drop only rows missing the variables we need
    df_reg = df.dropna(subset=needed_cols).copy()

    # Rename CO2 column so regressions are easier to read
    df_reg = df_reg.rename(columns={"value": "co2"})

    print("Rows in original df:", len(df))
    print("Rows used for regression (df_reg):", len(df_reg))
    print("Key columns available:", [c for c in ["has_dc", "gdp2022", "gdp2023", "gdp2024", "co2", "elec_price_2021"] if c in df_reg.columns])

# %% [markdown]
# ### ECONOMIC MODELS (county-level outcomes)
# Outcome: GDP (county level), predictor: has_dc, control: gdp2022 baseline GDP, and using robust standard errors (HC3)

# %%
# GDP 2023 regression
model_gdp2023 = smf.ols(                   # Create a regression model using statsmodels
    formula="gdp2023 ~ has_dc + gdp2022",  # regression formula
    data=df_reg                            # regression dataset
).fit(cov_type="HC3")                      # robust standard errors

print("GDP 2023 Regression Results")       #prints title
print(model_gdp2023.summary())             #prints full regression result table


# GDP 2024 regression
model_gdp2024 = smf.ols(                   # Create a regression model using statsmodels 
    formula="gdp2024 ~ has_dc + gdp2022",  #regression formula
    data=df_reg                            # Cleaned dataset
).fit(cov_type="HC3")                      # robust standard errors

print("\nGDP 2024 Regression Results")       # Prints title
print(model_gdp2024.summary())               # Prints full regression table

# %% [markdown]
# These regression models describe whether the counties hosting data centers experience different GDP outputs while controlling for baseline GDP in 2022. In both the 2023 and 2024 models, the coefficient of  has_dc is not statistically significant, indicating that counties with data centers don’t show significantly different GDP levels compared to counties without data centers. But, the coefficient for gdp2022 is statistically significant in both models, which suggest that previous economic performance is a strong predictor of future GDP. In general, these results indicate that baseline economic conditions explain GDP variation more strongly than the presence of data centers alone.

# %% [markdown]
# ### Environmental Models
# CO2 and electricity price are state-level variables

# %%
# CO2 regression
model_co2 = smf.ols( # Create a regression model using statsmodels 
    formula="co2 ~ has_dc",  # Regression formula, outcome variable = co2, predictor variable = has_dc
    data=df_reg     # This is to use the cleaned regression dataframe
).fit(cov_type="HC3")    # This fits the regression model and helps to make the results more reliable

print("\nCO2 Emissions Regression Results")    # Prints a clear title
print(model_co2.summary())                      # Prints the full regression results table


# Electricity price regression
model_elec = smf.ols(                     # Creates another regression model
    formula="elec_price_2021 ~ has_dc",    # regression formula, outcome variable = elec_price_2021, predictor variable = has_dc
    data=df_reg                             # Used for a cleaned regression dataframe
).fit(cov_type="HC3")                         # Run the regression model 

print("\nElectricity Price Regression Results")  # Prints the full regression results table
print(model_elec.summary())

# %% [markdown]
# These environmental modes examine whether the presence of data centers is associated with differences in CO2 emissions and electricity prices. The CO2 regression shows that the coefficient for has_dc is not statistically significant, which shows that the counties hosting data centers don’t appear to have significantly different CO2 emission levels compared to those without data centers. An explanation for this is that the CO2 emissions levels are measured at the state level, which may not capture county level environmental impacts. For the electricity price model, it shows a small positive association between data center presence and electricity prices, but the result is marginally significant. This suggests that increased electricity demand from data centers may slightly influence local electricity pricing but the evidence is weak to confirm a clear relationship.

# %% [markdown]
# #### Regression Interpretation
#
# Overall, the regression results provide limited evidence that the presence of data centers significantly affects county level economic outcomes. While baseline GDP strongly predicts future GDP levels, the presence of data centers alone doesn’t appear to have a significant difference in GDP. Environmental models also show no statistically significant relationship between data center presence and CO2 emissions, likely due to emission being measured at the state level rather than the county level. The electricity price model suggest a small positive association with data center presence, which shows that increased electricity demand may slightly influence local electricity markets.

# %% [markdown]
# # Section 4: EDA Summary and Interpretation
#
# In this section, we synthesize the main findings from our exploratory data analysis rather than repeating all earlier visualizations. Our goal is to connect the most important EDA patterns back to the research question: whether counties with data centers differ economically or environmentally from counties without them.
#
# The variables most relevant to our hypothesis are:
#
# - GDP
# - CO₂ emissions per capita
# - Electricity price
# - Water usage per capita
#
# Rather than reproducing earlier plots, this section summarizes the main takeaways and provides a compact statistical comparison between treated and control counties.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

state_dc_counts = df.groupby("state")["has_dc"].sum().sort_values(ascending=False).head(15)

plt.figure(figsize=(10,6))
sns.barplot(x=state_dc_counts.index, y=state_dc_counts.values)

plt.title("Top 15 States by Number of Counties with Data Centers")
plt.xlabel("State")
plt.ylabel("Number of Counties with Data Centers")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Data Centers Across States
#
# The plot above shows that data centers are not evenly distributed across the country. Instead, counties with data centers are concentrated in a relatively small number of states. This geographic clustering suggests that data center placement is influenced by regional infrastructure, energy access, and economic conditions rather than being randomly distributed.

# %%
plt.figure(figsize=(8,6))

sns.boxplot(data=df, x="has_dc", y="gdp2023")

plt.title("GDP Growth (2023): Counties With vs Without Data Centers")
plt.xlabel("Data Center Presence (0 = No, 1 = Yes)")
plt.ylabel("GDP Growth 2023")

plt.show()

# %% [markdown]
# ### GDP Comparison
#
# The GDP boxplot suggests that counties with data centers tend to show higher GDP growth values than counties without data centers. This pattern may indicate that data centers are more often located in already economically strong counties. Because of this, the relationship should not be interpreted as causal from EDA alone, and regression analysis is needed to account for baseline differences.

# %%
co2_filtered = df[df["co2_per_capita"] < df["co2_per_capita"].quantile(0.95)]

plt.figure(figsize=(8,6))

sns.boxplot(data=co2_filtered, x="has_dc", y="co2_per_capita")

plt.title("CO₂ Emissions per Capita: Counties With vs Without Data Centers")
plt.xlabel("Data Center Presence (0 = No, 1 = Yes)")
plt.ylabel("CO₂ per Capita")

plt.yscale("log")
plt.show()

# %% [markdown]
# ### CO₂ Emissions per Capita
#
# After trimming extreme outliers, the CO₂ per capita distribution shows substantial variability in both groups. Counties with data centers may show somewhat different emission patterns, but the overlap remains large. This suggests that data center presence alone may not fully explain differences in emissions, since other regional factors such as industrial activity and energy mix likely also contribute.

# %%
plt.figure(figsize=(8,6))

sns.boxplot(data=df, x="has_dc", y="elec_price_2021")

plt.title("Electricity Price: Counties With vs Without Data Centers")
plt.xlabel("Data Center Presence (0 = No, 1 = Yes)")
plt.ylabel("Electricity Price (2021)")

plt.show()

# %% [markdown]
# ### Electricity Prices
#
# Electricity prices vary across counties with and without data centers, but there is not an immediately dramatic separation between the two groups. This suggests electricity prices may influence location decisions for data centers, though the relationship is not strong enough to interpret visually without further modeling.

# %%
water_filtered = df[df["water_per_capita"] < df["water_per_capita"].quantile(0.95)]

plt.figure(figsize=(8,6))

sns.boxplot(data=water_filtered, x="has_dc", y="water_per_capita")

plt.title("Water Usage per Capita: Counties With vs Without Data Centers")
plt.xlabel("Data Center Presence (0 = No, 1 = Yes)")
plt.ylabel("Water Usage per Capita")

plt.yscale("log")
plt.show()

# %% [markdown]
# ### Water Usage per Capita
#
# Water usage per capita also varies substantially across counties. Counties with data centers may show somewhat higher water use, which is plausible given the cooling demands of large computing facilities. However, the wide spread in both groups indicates that water use is also shaped by many non-data-center factors.

# %%
summary_stats = df.groupby("has_dc")[[
    "gdp2023",
    "co2_per_capita",
    "elec_price_2021",
    "water_per_capita"
]].agg(["mean", "median"])

summary_stats

# %% [markdown]
# ### Section 4 Summary
#
# Overall, the visualizations suggest that counties with data centers differ from counties without data centers in several important ways. Data centers are geographically clustered, host counties often have stronger economic indicators, and environmental variables such as CO₂ emissions and water usage show substantial variation across both groups.
#
# These results are useful for identifying patterns in the data, but they do not establish causation. For that reason, the next step is regression analysis, which allows us to test whether these relationships remain after accounting for baseline differences between counties.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# In analyzing factors such as CO₂ emissions and electricity use, we recognize that environmental conditions in certain areas may be influenced by geographic location, climate, or existing infrastructure rather than being solely attributable to data center resource usage. To address this potential collection bias, we remain mindful of external and contextual factors that could skew interpretations of the data and acknowledge these limitations when drawing conclusions.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#        Though we are analyzing factors such as CO₂ emissions and electricity use, the environmental impacts in a certain area could be in worse conditions due to location rather than being simply a result of data center resource usage.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#        By potentially generalizing information to county-specific and not including individual’s data, the exposure of PII would be minimized.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#        All the information that we plan to use from datasets would be from publicly available databases, so no confidential and secure data could be potentially compromised.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#        A stakeholder’s perspective that may need to be considered are those of the team behind the data centers (who are subject matter experts), explaining the outcomes and necessary parts that go into powering data centers. This missing perspective may provide crucial insight and context into whatever we analyze from the data to answer our research question.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#     Same as mentioned previously, analyzing factors such as CO₂ emissions and electricity use, their specific environmental impacts in a certain area could be resulting in more concerning data due to location rather than being simply a result of data center resource usage (which could be omitted confounding variables).
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#     This project doesn't require us to be building or deploying a predictive model, just addressing ethical concerns related to how our data analysis/results can be potentially interpreted. Environmental and economic conditions differ immensely from county to county, so certain patterns within the data could be mistaken as simple cause-and-effect relationships when they are actually just correlations. There is also a risk these countries which are hosting AI data centers could be judged unfairly if differences in their specific infrastructure, climate, or local government policies are not taken into account.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#     To address these concerns previously listed, our team will be very diligent in explaining our limitations of the analysis and avoiding making causal claims without a strong reason to do so. We will present our results with appropriate context and acknowledge uncertainty in the data. By framing our conclusions carefully and avoiding generalizations, we aim to reduce the risk of our findings being misinterpreted.

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
