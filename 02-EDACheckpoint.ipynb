# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# - Athena Vimal: Background research, conceptualization, Writing – original draft, Writing – review & editing
# - Lucy Pan: Data preparation- cleaning/merging datasets, treatment variables
# - Kimberly Haro: Background research, data curation, writing– original draft, and writing– review & editing
# - Ruth Mazariego: Conceptualization, Hypothesis, Data curation, writing– original draft, and writing– review & editing
# - Duglas Zacarias: Data curation, Background research, Writing – original draft, Writing – review & editing

# %% [markdown]
# # Research Question

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your data checkpoint feedback

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress:  50%|█████     | 1/2 [00:00<00:00,  7.98it/s]
# Successfully downloaded: airline-safety.csv
# ...
# Overall Download Progress: 100%|██████████| 2/2 [00:00<00:00,  5.94it/s]
# Successfully downloaded: bad-drivers.csv

# %% [markdown]
# ### Dataset #1
#
# Instructions: REPLACE the contents of this cell and the one below with your work, including any updates to recover points lost in your data checkpoint feedback

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ### Dataset #2
#  as above, add any more copies of this that you need to given how many datasets you have

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### Our datasets
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '00-ProjectProposal.ipynb',
#  '.ipynb_checkpoints',
#  'modules',
#  '03-FinalProject.ipynb',
#  'README.md',
#  '01-DataCheckpoint.ipynb',
#  '02-EDACheckpoint.ipynb',
#  'results',
#  'data']

# %%
os.listdir("data")
# Out:
# ['02-processed', 'README.md', '00-raw', '01-interim']

# %%
os.listdir("data/02-processed")
# Out:
# ['df_water_clean.csv',
#  'df_counties.csv',
#  'df_countygdp_clean.csv',
#  'df_electricity_clean.csv',
#  '.gitkeep',
#  'df_datacenters_clean.csv',
#  'df_emissions_clean.csv']

# %%
# loading clean datasets
import pandas as pd
df_dc = pd.read_csv("data/02-processed/df_datacenters_clean.csv")
df_countygdp = pd.read_csv("data/02-processed/df_countygdp_clean.csv")
df_emissions = pd.read_csv("data/02-processed/df_emissions_clean.csv")
df_water = pd.read_csv("data/02-processed/df_water_clean.csv")
df_electricity = pd.read_csv("data/02-processed/df_electricity_clean.csv")

# %%
# df emissions
df_co2 = df_emissions[(df_emissions['sector-name']=='Industrial carbon dioxide emissions') & (df_emissions['year']==2021) & (df_emissions['fuel-name'] == 'All Fuels')]
df_co2 = df_co2.rename(columns={
    'state-name': 'state',
})

# new df counties: containing all counties 
df_counties = df_countygdp[['county']].copy()

#saving df counties to data/02processed
df_counties.to_csv('data/02-processed/df_counties.csv',index=False)

#aggregating total sqft per county in df_dc
total_sqft = df_dc.groupby(['state','county'])['sqft'].sum().reset_index()
total_sqft.rename(columns={'sqft':'total_sqft'}, inplace=True)

# getting columns in df electricity for 2021
elec_2021_cols = [col for col in df_electricity.columns if "2021" in col]
df_electricity['elec_price_2021'] = df_electricity[elec_2021_cols].mean(axis=1)
df_electricity = df_electricity[['state', 'elec_price_2021']].copy()

# %%
df_dc.head()
# Out:
#          id           state      county        sqft
# 0   2744301      New Jersey   Middlesex    105786.0
# 1   9474864  North Carolina    Caldwell   3407194.0
# 2  13924557            Iowa        Polk  11169421.0
# 3  14593270  North Carolina     Catawba   5431080.0
# 4  14930068      New Mexico  Bernalillo    158463.0

# %%
df_co2.head()
# Out:
#        year       state                          sector-name  fuel-name  \
# 58838  2021     Alabama  Industrial carbon dioxide emissions  All Fuels
# 58860  2021      Alaska  Industrial carbon dioxide emissions  All Fuels
# 58868  2021     Arizona  Industrial carbon dioxide emissions  All Fuels
# 58902  2021    Arkansas  Industrial carbon dioxide emissions  All Fuels
# 58912  2021  California  Industrial carbon dioxide emissions  All Fuels
#
#            value
# 58838  19.640576
# 58860  18.390715
# 58868   4.625649
# 58902   8.281442
# 58912  63.945572

# %%
df_countygdp.head()
# Out:
#    GeoFIPS   county  gdp2022  gdp2023  gdp2024    state
# 0     1001  Autauga      8.4      1.3     -7.8  Alabama
# 1     1003  Baldwin      6.1      7.6      2.8  Alabama
# 2     1005  Barbour     -1.2     -2.4      2.4  Alabama
# 3     1007     Bibb     -0.4      2.8      0.9  Alabama
# 4     1009   Blount      0.8      4.3      8.2  Alabama

# %%
df_water.head()
# Out:
#      state  STATEFIPS    county  COUNTYFIPS  FIPS  YEAR  TP-TotPop PS-GWPop  \
# 0  Alabama          1  Autauga            1  1001  2015     55.347       --
# 1  Alabama          1  Baldwin            3  1003  2015    203.709       --
# 2  Alabama          1  Barbour            5  1005  2015     26.489       --
# 3  Alabama          1     Bibb            7  1007  2015     22.583       --
# 4  Alabama          1   Blount            9  1009  2015     57.673       --
#
#   PS-SWPop  PS-TOPop  ...  TO-WGWTo  TO-WSWFr  TO-WSWSa  TO-WSWTo  TO-WFrTo  \
# 0       --    48.998  ...     10.69     45.72       0.0     45.72     56.41
# 1       --   174.907  ...     73.38     11.32       0.0     11.32     84.70
# 2       --    24.587  ...      6.06      2.96       0.0      2.96      9.02
# 3       --    20.947  ...      5.67      0.20       0.0      0.20      5.87
# 4       --    44.815  ...      4.64     55.43       0.0     55.43     60.07
#
# ...

# %%
df_electricity.head()
# Out:
#            state  elec_price_2021
# 0    Connecticut        16.527500
# 1          Maine        12.906667
# 2  Massachusetts        16.954167
# 3  New Hampshire        16.142500
# 4   Rhode Island        15.532500

# %%
# cleaning names of counties and states functions

def clean_county(county):
    county = str(county).strip().lower()

    for suffix in [" county", 
               " parish", 
               " borough", 
               " census area", 
               " municipality", 
               "city and borough"]:
        if county.endswith(suffix):
            county = county[:-len(suffix)]
    return county

def clean_state(state):
    state = str(state).strip().lower()
    return state

for df in [df_dc, df_countygdp, total_sqft, df_water]:
    df['county'] = df['county'].apply(clean_county)
    df['state'] = df['state'].apply(clean_state)

df_co2['state'] = df_co2['state'].apply(clean_state)
df_electricity['state'] = df_electricity['state'].apply(clean_state)

# %% [markdown]
# #### Merging datasets

# %%
# merging county gdp with total sqft from df_dc
df = df_countygdp.merge(total_sqft, on=['state','county'],how='left')

#filling nan sqft with 0
df['total_sqft'] = df['total_sqft'].fillna(0)

#merging df w df_water
df = df.merge(df_water, on=['state','county'], how='left')

#merging df w df_co2
df = df.merge(df_co2, on=['state'], how='left')

#merging df w df_electricity

df = df.merge(df_electricity, on=['state'], how='left')

#dropping irrelevant columns 

df
# Out:
#       GeoFIPS      county  gdp2022  gdp2023  gdp2024    state  total_sqft  \
# 0        1001     autauga      8.4      1.3     -7.8  alabama         0.0
# 1        1003     baldwin      6.1      7.6      2.8  alabama         0.0
# 2        1005     barbour     -1.2     -2.4      2.4  alabama         0.0
# 3        1007        bibb     -0.4      2.8      0.9  alabama         0.0
# 4        1009      blount      0.8      4.3      8.2  alabama         0.0
# ...       ...         ...      ...      ...      ...      ...         ...
# 3059    56037  sweetwater     -4.1      4.0     -7.8  wyoming         0.0
# 3060    56039       teton     -1.8      4.3      2.8  wyoming         0.0
# 3061    56041       uinta      4.3      0.7      1.4  wyoming         0.0
# 3062    56043    washakie     -1.2      2.5     -1.3  wyoming         0.0
# 3063    56045      weston      0.3      3.4      9.9  wyoming         0.0
#
#       STATEFIPS  COUNTYFIPS     FIPS  ...  TO-WSaTo  TO-Wtotl TO-CUsFrPartial  \
# ...

# %% [markdown]
# #### Creating treatment variables

# %%
# has_dc: 1 if county has a data center, 0 otherwise
df['has_dc'] = df['total_sqft'].apply(lambda x: 1 if x > 0 else 0)

# large_dc if sqft over 1,000,000, 1 if yes, 0 otherwise
df['large_dc'] = df['total_sqft'].apply(lambda x: 1 if x > 1_000_000 else 0)

# %%
print(df['has_dc'].value_counts())
print(df['large_dc'].value_counts())
# Out:
# has_dc
# 0    2847
# 1     217
# Name: count, dtype: int64
# large_dc
# 0    2992
# 1      72
# Name: count, dtype: int64

# %% [markdown]
# #### Section 1 of EDA - Economic Variable Analysis
#
# This part compares the baseline GDP for counties, as well as visualizing economic variables through SMD and boxplots.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

econ_vars = [
    "gdp2022",
    "gdp2023",
    "gdp2024",
    "elec_price_2021",
    "total_sqft"
]

df_econ = df[econ_vars + ["has_dc", "large_dc"]].copy()

print(df_econ.describe())
# Out:
#            gdp2022      gdp2023      gdp2024  elec_price_2021    total_sqft  \
# count  3064.000000  3064.000000  3064.000000      3064.000000  3.064000e+03
# mean      1.137108     4.415274     2.218832        10.412549  2.658073e+05
# std       7.579484     9.921999     7.704917         2.219411  2.516598e+06
# min     -37.000000   -36.800000   -46.300000         7.735833  0.000000e+00
# 25%      -2.100000     0.200000    -0.200000         9.077500  0.000000e+00
# 50%       1.200000     2.800000     2.300000        10.139167  0.000000e+00
# 75%       4.225000     6.400000     4.800000        10.833333  0.000000e+00
# max      78.100000   118.800000    76.600000        30.855833  5.865350e+07
#
#             has_dc     large_dc
# count  3064.000000  3064.000000
# mean      0.070822     0.023499
# std       0.256570     0.151506
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# ...

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x="has_dc", y="gdp2022", data=df)
plt.title("Baseline GDP (2022) by Data Center Presence")
plt.xlabel("Has Data Center (0=No, 1=Yes)")
plt.ylabel("GDP 2022 Growth (%)")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df[econ_vars])
plt.xticks(rotation=45)
plt.title("Distribution of Economic Variables")
plt.show()

# %%
gdp_means = df.groupby("has_dc")["gdp2022"].mean()
print("Mean GDP 2022 by Data Center Presence:")
print(gdp_means)

def compute_smd(data, treatment, variable):
    group1 = data[data[treatment] == 1][variable]
    group0 = data[data[treatment] == 0][variable]
    
    mean1 = group1.mean()
    mean0 = group0.mean()
    
    sd_pooled = np.sqrt((group1.var() + group0.var()) / 2)
    
    return (mean1 - mean0) / sd_pooled

smd_results = {}

for var in econ_vars:
    smd_results[var] = compute_smd(df, "has_dc", var)

smd_df = pd.DataFrame.from_dict(smd_results, orient="index", columns=["SMD"])
print(smd_df)

plt.figure(figsize=(7,5))

plt.axvline(x=0.1, linestyle="--")
plt.axvline(x=-0.1, linestyle="--")

sns.barplot(x=smd_df["SMD"], y=smd_df.index)

plt.title("Standardized Mean Differences (Data Center vs No Data Center)")
plt.xlabel("SMD")
plt.show()
# Out:
# Mean GDP 2022 by Data Center Presence:
# has_dc
# 0    1.020864
# 1    2.662212
# Name: gdp2022, dtype: float64
#                       SMD
# gdp2022          0.269149
# gdp2023         -0.143809
# gdp2024          0.085753
# elec_price_2021  0.145162
# total_sqft       0.606214

# %% [markdown]
# #### Section 2 of EDA - Environmental Data Analysis

# %% [markdown]
# This part compates the state-level CO2 emmisons (per capita), water usage (indistrial per capita), and electricity prices. It produced visualizatins to better understand trends and differences between states.
#
# Notes:
# - Data comes from multiple years; some datasets may not align exactly.
# - Missing values have been handled by dropping incomplete rows.
# - Regression models are illustrative and not predictive becasue at the moment is from inconsistent years.

# %%
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Create derived columns
# CO2 per capita (if TP-TotPop exists)
if 'TP-TotPop' in df.columns:
    df['co2_per_capita'] = df['value'] / df['TP-TotPop']
else:
    df['co2_per_capita'] = df['value']  # fallback if no population column

# CO2 per GDP
df['co2_per_gdp'] = df['value'] / df['gdp2022'] 

# Water withdrawals per capita (using TO-Wtotl)
df['water_per_capita'] = df['TO-Wtotl'] / df['TP-TotPop'] if 'TP-TotPop' in df.columns else df['TO-Wtotl']


# 2. State-level electricity prices
state_elec = df.groupby('state')['elec_price_2021'].mean().reset_index()

plt.figure(figsize=(12,5))
sns.barplot(data=state_elec, x='state', y='elec_price_2021')
plt.xticks(rotation=45, fontsize=8)
plt.title("State-level Average Electricity Price (2021)")
plt.ylabel("Electricity Price ($/kWh)")
plt.show()

# Regression model for CO2 per capita

# Uses has_dc, gdp2022, total water, and state
model_co2 = smf.ols(
    'co2_per_capita ~ has_dc + gdp2022 + Q("TO-Wtotl") + C(state)',
    data=df
).fit()

print(model_co2.summary())

# Visualizations

# CO2 per capita by state
plt.figure(figsize=(12,5))
sns.barplot(data=df, x='state', y='co2_per_capita')
plt.xticks(rotation=45, fontsize=8)
plt.title("CO2 Emissions per Capita by State")
plt.ylabel("CO2 per Capita")
plt.show()

# Water per capita by state
plt.figure(figsize=(12,5))
sns.barplot(data=df, x='state', y='water_per_capita')
plt.xticks(rotation=45, fontsize=8)
plt.title("Water Withdrawals per Capita by State")
plt.ylabel("Water per Capita (units of TO-Wtotl)")
plt.show()

# CO2 vs Water scatterplot
plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x='water_per_capita', y='co2_per_capita', hue='state')
plt.title("CO2 per Capita vs Water per Capita")
plt.xlabel("Water per Capita")
plt.ylabel("CO2 per Capita")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         co2_per_capita   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     4.810
# Date:                Thu, 05 Mar 2026   Prob (F-statistic):           6.86e-26
# Time:                        02:00:10   Log-Likelihood:                -15921.
# No. Observations:                3045   AIC:                         3.195e+04
# Df Residuals:                    2993   BIC:                         3.226e+04
# Df Model:                          51
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      1.7248      5.580      0.309      0.757      -9.216      12.666
# ...

# %% [markdown]
# # Section 3 of EDA- Regression Analysis

# %% [markdown]
# In this section, we run simple OLS (ordinary least squares) regression models using has_dc (a binary indicator for whether a county hosts at least one data center) as the main explanatory variable. We focus on economic outcomes using county GDP (2022-2024) and environmental outcomes using CO2 emissions and electricity price. Because CO2 and electricity price measures are available at the state level in the datasets we currently have, we interpret environmental regressions as broarder association and avoid making strong county-level claims. This regression analysis aligns with oour hypothesis that host locations may experience both economic gains and environmental costs

# %%
#Prepare a dataset for regression 
import statsmodels.formula.api as smf

# %%
# list of the variables needed for the regression models
# Columns we need for the regressions in this section
# NOTE: CO2 is currently stored in the column named "value"
needed_cols = ["has_dc", "gdp2022", "gdp2023", "gdp2024", "value", "elec_price_2021"]

# Check if any needed columns are missing
missing = [col for col in needed_cols if col not in df.columns]

if len(missing) > 0:
    print("Missing columns in df:", missing)
    print("Fix: Run the earlier merge/cleaning cells that create df, then run this section again.")
else:
    # Drop only rows missing the variables we need
    df_reg = df.dropna(subset=needed_cols).copy()

    # Rename CO2 column so regressions are easier to read
    df_reg = df_reg.rename(columns={"value": "co2"})

    print("Rows in original df:", len(df))
    print("Rows used for regression (df_reg):", len(df_reg))
    print("Key columns available:", [c for c in ["has_dc", "gdp2022", "gdp2023", "gdp2024", "co2", "elec_price_2021"] if c in df_reg.columns])
# Out:
# Rows in original df: 3064
# Rows used for regression (df_reg): 3064
# Key columns available: ['has_dc', 'gdp2022', 'gdp2023', 'gdp2024', 'co2', 'elec_price_2021']

# %% [markdown]
# ### ECONOMIC MODELS (county-level outcomes)
# Outcome: GDP (county level), predictor: has_dc, control: gdp2022 baseline GDP, and using robust standard errors (HC3)

# %%
# GDP 2023 regression
model_gdp2023 = smf.ols(
    formula="gdp2023 ~ has_dc + gdp2022",  # regression formula
    data=df_reg                            # regression dataset
).fit(cov_type="HC3")                      # robust standard errors

print("GDP 2023 Regression Results")
print(model_gdp2023.summary())


# GDP 2024 regression
model_gdp2024 = smf.ols(
    formula="gdp2024 ~ has_dc + gdp2022",
    data=df_reg
).fit(cov_type="HC3")                      # robust standard errors

print("\nGDP 2024 Regression Results")
print(model_gdp2024.summary())
# Out:
# GDP 2023 Regression Results
#                             OLS Regression Results
# ...
# Dep. Variable:                gdp2023   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     30.99
# Date:                Thu, 05 Mar 2026   Prob (F-statistic):           4.75e-14
# Time:                        02:00:15   Log-Likelihood:                -11262.
# No. Observations:                3064   AIC:                         2.253e+04
# Df Residuals:                    3061   BIC:                         2.255e+04
# Df Model:                           2
# Covariance Type:                  HC3
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.8569      0.201     24.118      0.000       4.462       5.252
# ...

# %% [markdown]
# ### Environmental Models
# CO2 and electricity price are state-level variables

# %%
# CO2 regression
model_co2 = smf.ols(
    formula="co2 ~ has_dc",
    data=df_reg
).fit(cov_type="HC3")

print("\nCO2 Emissions Regression Results")
print(model_co2.summary())


# Electricity price regression
model_elec = smf.ols(
    formula="elec_price_2021 ~ has_dc",
    data=df_reg
).fit(cov_type="HC3")

print("\nElectricity Price Regression Results")
print(model_elec.summary())
# Out:
# CO2 Emissions Regression Results
#                             OLS Regression Results
# ...
# Dep. Variable:                    co2   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.7287
# Date:                Thu, 05 Mar 2026   Prob (F-statistic):              0.393
# Time:                        02:00:15   Log-Likelihood:                -17091.
# No. Observations:                3064   AIC:                         3.419e+04
# Df Residuals:                    3062   BIC:                         3.420e+04
# Df Model:                           1
# Covariance Type:                  HC3
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.4482      1.205     31.081      0.000      35.087      39.810
# ...

# %% [markdown]
# ### Regression Interpretation
# The regression analysis finds limited evidence that counties hosting data centers experience significantly different economic outcomes compared counties wihtout data centers once baseline GDP levels are considered. In both 2023 and 2024 models, the coefficient for has_dc is not statistically significant, suggesting that the presence of data centers alone doesn't strongly predict county GDP differences in this dataset. Environemntal models also show no statistically significant relationship between data centers presence and CO2 emissions, probably since the emissions are measired at the state level instead of the county level. The electricity price model show a small positive association with data center presence.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: Replace this with your timeline.  **PLEASE UPDATE your Timeline!** No battle plan survives contact with the enemy, so make sure we understand how your plans have changed.  Also if you have lost points on the previous checkpoint fix them
